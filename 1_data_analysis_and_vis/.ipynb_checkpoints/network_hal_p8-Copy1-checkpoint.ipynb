# %%
import pandas as pd
import os
import glob
import datetime
import json
import re
import tqdm
import requests
from requests.exceptions import HTTPError

# %%
#Library for social network analysis
import networkx as nx
import networkx.algorithms.community as nx_comm
from networkx.algorithms import bipartite
#import bamboolib
import pelote
from ipysigma import Sigma
import numpy as np
#import plotly.express as px

# %% [markdown]
# # Chargement des fichiers de données
#
# On part du fichier fournit par le MESR qui est au format jsonl. On veut le passer en csv pour faciliter les manipulations

# %%
file_path = "../Data/fichier_from_MESR/bso-publications-latest_199318270_enriched.jsonl"
list_id_pub = []
datas =[]
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        try:
            data = json.loads(line)
            # Extract specific fields
            ids = data.get('all_ids')
            list_id_pub.append(ids[0])
            datas.append(data)
            
        except json.JSONDecodeError:
            continue  # Skip invalid lines

# %%
datas[0]
# Out:
# {'all_ids': ['halhal-03933378', 'naturalf8f5d55c1bafa6553b6502f859b457e1'],
#  'authors': [{'hal_docid': '28862-176081',
#    'first_name': 'Jérôme',
#    'last_name': 'Livet',
#    'full_name': 'Jérôme Livet',
#    'id_hal_i': '176081',
#    'id_hal_s': 'jerome-livet',
#    'orcid': '0000-0002-1785-776X',
#    'author_position': 1,
#    'role': 'aut',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Institut national de recherches archéologiques préventives, Inrap, 121 rue d'Alésia75014 Paris, France",
#      'hal_docid': '301475',
#      'country': 'France',
#      'structId': '301475'}],
#    'datasource': 'hal'},
#   {'hal_docid': '7952-15426',
#    'first_name': 'François',
#    'last_name': 'Capron',
#    'full_name': 'François Capron',
#    'id_hal_i': '15426',
#    'idref': '076914968',
#    'id_hal_s': 'francois-capron',
#    'author_position': 2,
#    'role': 'aut',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Institut national de recherches archéologiques préventives, Inrap, 121 rue d'Alésia75014 Paris, France",
#      'hal_docid': '301475',
#      'country': 'France',
#      'structId': '301475'}],
#    'datasource': 'hal'},
#   {'hal_docid': '31854-18849',
#    'first_name': 'Philippe',
#    'last_name': 'Blanchard',
#    'full_name': 'Philippe Blanchard',
#    'id_hal_i': '18849',
#    'id_hal_s': 'philippe-blanchard',
#    'idref': '253890713',
#    'orcid': '0000-0003-0829-7737',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Institut national de recherches archéologiques préventives, Inrap, 121 rue d'Alésia75014 Paris, France",
#      'hal_docid': '301475',
#      'country': 'France',
#      'structId': '301475'},
#     {'detected_countries': ['fr'],
#      'name': "De la Préhistoire à l'Actuel : Culture, Environnement et Anthropologie, UMR5199, PACEA, UB, CNRS, Université de Bordeaux, Centre National de la Recherche Scientifique, Université de Bordeaux - Bâtiment B8 - CS50023 - Allée Geoffroy-Saint-Hilaire - 33615 Pessac Cedex, France",
#      'hal_docid': '205557',
#      'country': 'France',
#      'rnsr': '200411870P',
#      'ror': 'https://ror.org/027mnq498',
#      'structId': '205557'},
#     {'detected_countries': ['fr'],
#      'name': 'Université de Bordeaux, UB, 35, place Pey Berland - 33076 Bordeaux, France',
#      'hal_docid': '259761',
#      'country': 'France',
#      'ror': 'https://ror.org/057qpr032',
#      'structId': '259761'},
#     {'detected_countries': ['fr'],
#      'name': 'Centre National de la Recherche Scientifique, CNRS, France',
#      'hal_docid': '441569',
#      'country': 'France',
#      'ror': 'https://ror.org/02feahw73',
#      'structId': '441569'}],
#    'author_position': 3,
#    'role': 'aut',
#    'datasource': 'hal'},
#   {'hal_docid': '24307-245',
#    'first_name': 'Jean-Philippe',
#    'last_name': 'Chimier',
#    'full_name': 'Jean-Philippe Chimier',
#    'id_hal_i': '245',
#    'id_hal_s': 'jpchimier',
#    'idref': '253128498',
#    'orcid': '0009-0007-6738-4263',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Institut national de recherches archéologiques préventives, Inrap, 121 rue d'Alésia75014 Paris, France",
#      'hal_docid': '301475',
#      'country': 'France',
#      'structId': '301475'},
#     {'detected_countries': ['fr'],
#      'name': 'Cités, Territoires, Environnement et Sociétés, UMR 7324, UMR7324 / UMR6173, CITERES, UT, CNRS, Université de Tours, Centre National de la Recherche Scientifique, 33 allée Ferdinand de Lesseps BP 60449 37204 Tours cedex 3, France',
#      'hal_docid': '199947',
#      'country': 'France',
#      'rnsr': '201220233V',
#      'ror': 'https://ror.org/04ahza989',
#      'structId': '199947'},
#     {'detected_countries': ['fr'],
#      'name': "Université de Tours, UT, 60 rue du Plat d'Étain, 37020 Tours cedex 1, France",
#      'hal_docid': '300298',
#      'country': 'France',
#      'ror': 'https://ror.org/02wwzvj46',
#      'structId': '300298'},
#     {'detected_countries': ['fr'],
#      'name': 'Centre National de la Recherche Scientifique, CNRS, France',
#      'hal_docid': '441569',
#      'country': 'France',
#      'ror': 'https://ror.org/02feahw73',
#      'structId': '441569'}],
#    'author_position': 4,
#    'role': 'aut',
#    'datasource': 'hal'},
#   {'hal_docid': '24237-6836',
#    'first_name': 'Agnès',
#    'last_name': 'Couderc',
#    'full_name': 'Agnès Couderc',
#    'id_hal_i': '6836',
#    'idref': '230274544',
#    'id_hal_s': 'agnes-couderc',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': 'Cités, Territoires, Environnement et Sociétés, UMR 7324, UMR7324 / UMR6173, CITERES, UT, CNRS, Université de Tours, Centre National de la Recherche Scientifique, 33 allée Ferdinand de Lesseps BP 60449 37204 Tours cedex 3, France',
#      'hal_docid': '199947',
#      'country': 'France',
#      'rnsr': '201220233V',
#      'ror': 'https://ror.org/04ahza989',
#      'structId': '199947'},
#     {'detected_countries': ['fr'],
#      'name': "Université de Tours, UT, 60 rue du Plat d'Étain, 37020 Tours cedex 1, France",
#      'hal_docid': '300298',
#      'country': 'France',
#      'ror': 'https://ror.org/02wwzvj46',
#      'structId': '300298'},
#     {'detected_countries': ['fr'],
#      'name': 'Centre National de la Recherche Scientifique, CNRS, France',
#      'hal_docid': '441569',
#      'country': 'France',
#      'ror': 'https://ror.org/02feahw73',
#      'structId': '441569'},
#     {'detected_countries': ['fr'],
#      'name': "Institut national de recherches archéologiques préventives, Inrap, 121 rue d'Alésia75014 Paris, France",
#      'hal_docid': '301475',
#      'country': 'France',
#      'structId': '301475'}],
#    'author_position': 5,
#    'role': 'aut',
#    'datasource': 'hal'},
#   {'hal_docid': '45322-2483',
#    'first_name': 'Matthieu',
#    'last_name': 'Gaultier',
#    'full_name': 'Matthieu Gaultier',
#    'id_hal_i': '2483',
#    'id_hal_s': 'matthieu-gaultier',
#    'idref': '070484031',
#    'orcid': '0000-0002-7599-4906',
#    'author_position': 6,
#    'role': 'aut',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Service de l'archéologie du département d'Indre-et-Loire, SADIL, Conseil général d'Indre-et-Loire, Hôtel du Département, Place de la Préfecture, 37927 Tours Cedex 9, France",
#      'hal_docid': '408770',
#      'country': 'France',
#      'structId': '408770'}],
#    'datasource': 'hal'},
#   {'hal_docid': '1586948-0',
#    'first_name': 'Aurelie',
#    'last_name': 'Mayer',
#    'full_name': 'Aurelie Mayer',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': 'EVEHA (Etudes et valorisations archeologiques), 31 rue Soyouz - ESTER Technopole87 068 LIMOGES CedexTel : 05 55 10 98 72contact@eveha.fr, France',
#      'hal_docid': '363687',
#      'country': 'France',
#      'structId': '363687'}],
#    'author_position': 7,
#    'role': 'aut',
#    'datasource': 'hal'},
#   {'hal_docid': '31677-12929',
#    'first_name': 'Isabelle',
#    'last_name': 'Pichon',
#    'full_name': 'Isabelle Pichon',
#    'id_hal_i': '12929',
#    'idref': '174214952',
#    'id_hal_s': 'isabelle-pichon',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Institut national de recherches archéologiques préventives, Inrap, 121 rue d'Alésia75014 Paris, France",
#      'hal_docid': '301475',
#      'country': 'France',
#      'structId': '301475'},
#     {'detected_countries': ['fr'],
#      'name': 'Cités, Territoires, Environnement et Sociétés, UMR 7324, UMR7324 / UMR6173, CITERES, UT, CNRS, Université de Tours, Centre National de la Recherche Scientifique, 33 allée Ferdinand de Lesseps BP 60449 37204 Tours cedex 3, France',
#      'hal_docid': '199947',
#      'country': 'France',
#      'rnsr': '201220233V',
#      'ror': 'https://ror.org/04ahza989',
#      'structId': '199947'},
#     {'detected_countries': ['fr'],
#      'name': "Université de Tours, UT, 60 rue du Plat d'Étain, 37020 Tours cedex 1, France",
#      'hal_docid': '300298',
#      'country': 'France',
#      'ror': 'https://ror.org/02wwzvj46',
#      'structId': '300298'},
#     {'detected_countries': ['fr'],
#      'name': 'Centre National de la Recherche Scientifique, CNRS, France',
#      'hal_docid': '441569',
#      'country': 'France',
#      'ror': 'https://ror.org/02feahw73',
#      'structId': '441569'}],
#    'author_position': 8,
#    'role': 'aut',
#    'datasource': 'hal'},
#   {'hal_docid': '548806-0',
#    'first_name': 'Yannick',
#    'last_name': 'Prouin',
#    'full_name': 'Yannick Prouin',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': 'EVEHA (Etudes et valorisations archeologiques), 31 rue Soyouz - ESTER Technopole87 068 LIMOGES CedexTel : 05 55 10 98 72contact@eveha.fr, France',
#      'hal_docid': '363687',
#      'country': 'France',
#      'structId': '363687'}],
#    'author_position': 9,
#    'role': 'aut',
#    'datasource': 'hal'},
#   {'hal_docid': '24234-18850',
#    'first_name': 'Philippe',
#    'last_name': 'Salé',
#    'full_name': 'Philippe Salé',
#    'id_hal_i': '18850',
#    'id_hal_s': 'philippe-sale',
#    'idref': '243420382',
#    'orcid': '0009-0002-8159-7293',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Institut national de recherches archéologiques préventives, Inrap, 121 rue d'Alésia75014 Paris, France",
#      'hal_docid': '301475',
#      'country': 'France',
#      'structId': '301475'},
#     {'detected_countries': ['fr'],
#      'name': 'Cités, Territoires, Environnement et Sociétés, UMR 7324, UMR7324 / UMR6173, CITERES, UT, CNRS, Université de Tours, Centre National de la Recherche Scientifique, 33 allée Ferdinand de Lesseps BP 60449 37204 Tours cedex 3, France',
#      'hal_docid': '199947',
#      'country': 'France',
#      'rnsr': '201220233V',
#      'ror': 'https://ror.org/04ahza989',
#      'structId': '199947'},
#     {'detected_countries': ['fr'],
#      'name': "Université de Tours, UT, 60 rue du Plat d'Étain, 37020 Tours cedex 1, France",
#      'hal_docid': '300298',
#      'country': 'France',
#      'ror': 'https://ror.org/02wwzvj46',
#      'structId': '300298'},
#     {'detected_countries': ['fr'],
#      'name': 'Centre National de la Recherche Scientifique, CNRS, France',
#      'hal_docid': '441569',
#      'country': 'France',
#      'ror': 'https://ror.org/02feahw73',
#      'structId': '441569'}],
#    'author_position': 10,
#    'role': 'aut',
#    'datasource': 'hal'},
#   {'hal_docid': '1522808-0',
#    'first_name': 'Florence',
#    'last_name': 'Tane',
#    'full_name': 'Florence Tane',
#    'author_position': 11,
#    'role': 'aut',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Institut national de recherches archéologiques préventives, Inrap, 121 rue d'Alésia75014 Paris, France",
#      'hal_docid': '301475',
#      'country': 'France',
#      'structId': '301475'}],
#    'datasource': 'hal'},
#   {'hal_docid': '1326674-0',
#    'first_name': 'Laure',
#    'last_name': 'Ziegler',
#    'full_name': 'Laure Ziegler',
#    'author_position': 12,
#    'role': 'aut',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Service Archéologique Municipal d'Orléans, 13 bis rue de la Tour Neuve45000 Orléans, France",
#      'hal_docid': '421076',
#      'country': 'France',
#      'structId': '421076'}],
#    'datasource': 'hal'},
#   {'hal_docid': '7697-0',
#    'first_name': 'Raphaël',
#    'last_name': 'Durand',
#    'full_name': 'Raphaël Durand',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Service d'archéologie préventive de Bourges Plus, MCC, Ministère de la Culture et de la Communication, France",
#      'hal_docid': '178256',
#      'country': 'France',
#      'structId': '178256'},
#     {'detected_countries': ['fr'],
#      'name': 'Ministère de la Culture et de la Communication, MCC, 3, rue de Valois 75001 Paris, France',
#      'hal_docid': '300125',
#      'country': 'France',
#      'ror': 'https://ror.org/017rnyz40',
#      'structId': '300125'}],
#    'author_position': 13,
#    'role': 'aut',
#    'datasource': 'hal'},
#   {'hal_docid': '1986791-1073401',
#    'first_name': 'Mickaël',
#    'last_name': 'Montaudon',
#    'full_name': 'Mickaël Montaudon',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': 'Département de Maine-et-Loire - Pôle archéologie, 108 Rue de Frémur, 49000 Angers, France',
#      'hal_docid': '1041663',
#      'country': 'France',
#      'structId': '1041663'}],
#    'author_position': 14,
#    'role': 'aut',
#    'datasource': 'hal'},
#   {'hal_docid': '39969-744498',
#    'first_name': 'Sandrine',
#    'last_name': 'Linger-Riquier',
#    'full_name': 'Sandrine Linger-Riquier',
#    'id_hal_i': '744498',
#    'id_hal_s': 'sandrine-linger-riquier',
#    'idref': '091303702',
#    'orcid': '0009-0002-6795-2084',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Institut national de recherches archéologiques préventives, Inrap, 121 rue d'Alésia75014 Paris, France",
#      'hal_docid': '301475',
#      'country': 'France',
#      'structId': '301475'},
#     {'detected_countries': ['fr'],
#      'name': 'Cités, Territoires, Environnement et Sociétés, UMR 7324, UMR7324 / UMR6173, CITERES, UT, CNRS, Université de Tours, Centre National de la Recherche Scientifique, 33 allée Ferdinand de Lesseps BP 60449 37204 Tours cedex 3, France',
#      'hal_docid': '199947',
#      'country': 'France',
#      'rnsr': '201220233V',
#      'ror': 'https://ror.org/04ahza989',
#      'structId': '199947'},
#     {'detected_countries': ['fr'],
#      'name': "Université de Tours, UT, 60 rue du Plat d'Étain, 37020 Tours cedex 1, France",
#      'hal_docid': '300298',
#      'country': 'France',
#      'ror': 'https://ror.org/02wwzvj46',
#      'structId': '300298'},
#     {'detected_countries': ['fr'],
#      'name': 'Centre National de la Recherche Scientifique, CNRS, France',
#      'hal_docid': '441569',
#      'country': 'France',
#      'ror': 'https://ror.org/02feahw73',
#      'structId': '441569'}],
#    'author_position': 15,
#    'role': 'aut',
#    'datasource': 'hal'},
#   {'hal_docid': '2690756-0',
#    'first_name': 'Émilie',
#    'last_name': 'Portat',
#    'full_name': 'Émilie Portat',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Archéologies et Sciences de l'Antiquité, UMR7041, UMR7041, UMR7041, UMR7041, ArScAn, UP1, UP8, UPN, MCC, CNRS, Université Paris 1 Panthéon-Sorbonne, Université Paris 8 Vincennes-Saint-Denis, Université Paris Nanterre, Ministère de la Culture et de la Communication, Centre National de la Recherche Scientifique, MSH Mondes (bâtiment René-Ginouvès). 21, allée de l’Université 92023 NANTERRE Cedex, France",
#      'hal_docid': '1003',
#      'country': 'France',
#      'rnsr': '199912442H',
#      'ror': 'https://ror.org/04wz9m339',
#      'structId': '1003'},
#     {'detected_countries': ['fr'],
#      'name': 'Université Paris 1 Panthéon-Sorbonne, UP1, 12 place du Panthéon, 75231 Paris Cedex 05, France',
#      'hal_docid': '7550',
#      'country': 'France',
#      'ror': 'https://ror.org/002t25c44',
#      'structId': '7550'},
#     {'detected_countries': ['fr'],
#      'name': 'Université Paris 8 Vincennes-Saint-Denis, UP8, 2 rue de la Liberté - 93526 Saint-Denis cedex, France',
#      'hal_docid': '11141',
#      'country': 'France',
#      'ror': 'https://ror.org/04wez5e68',
#      'structId': '11141'},
#     {'detected_countries': ['fr'],
#      'name': 'Université Paris Nanterre, UPN, 200 avenue de la République - 92001 Nanterre cedex, France',
#      'hal_docid': '116205',
#      'country': 'France',
#      'ror': 'https://ror.org/013bkhk48',
#      'structId': '116205'},
#     {'detected_countries': ['fr'],
#      'name': 'Ministère de la Culture et de la Communication, MCC, 3, rue de Valois 75001 Paris, France',
#      'hal_docid': '300125',
#      'country': 'France',
#      'ror': 'https://ror.org/017rnyz40',
#      'structId': '300125'},
#     {'detected_countries': ['fr'],
#      'name': 'Centre National de la Recherche Scientifique, CNRS, France',
#      'hal_docid': '441569',
#      'country': 'France',
#      'ror': 'https://ror.org/02feahw73',
#      'structId': '441569'},
#     {'detected_countries': ['fr'],
#      'name': "TranSphères, ArScAn, Archéologies et Sciences de l'Antiquité, MSH Mondes (bâtiment René-Ginouvès). 21, allée de l’Université 92023 NANTERRE Cedex, France",
#      'hal_docid': '1059646',
#      'country': 'France',
#      'structId': '1059646'},
#     {'detected_countries': ['fr'],
#      'name': "Archéologies et Sciences de l'Antiquité, UMR7041, UMR7041, UMR7041, UMR7041, ArScAn, UP1, UP8, UPN, MCC, CNRS, Université Paris 1 Panthéon-Sorbonne, Université Paris 8 Vincennes-Saint-Denis, Université Paris Nanterre, Ministère de la Culture et de la Communication, Centre National de la Recherche Scientifique, MSH Mondes (bâtiment René-Ginouvès). 21, allée de l’Université 92023 NANTERRE Cedex, France",
#      'hal_docid': '1003',
#      'country': 'France',
#      'rnsr': '199912442H',
#      'ror': 'https://ror.org/04wz9m339',
#      'structId': '1003'},
#     {'detected_countries': ['fr'],
#      'name': 'Université Paris 1 Panthéon-Sorbonne, UP1, 12 place du Panthéon, 75231 Paris Cedex 05, France',
#      'hal_docid': '7550',
#      'country': 'France',
#      'ror': 'https://ror.org/002t25c44',
#      'structId': '7550'},
#     {'detected_countries': ['fr'],
#      'name': 'Université Paris 8 Vincennes-Saint-Denis, UP8, 2 rue de la Liberté - 93526 Saint-Denis cedex, France',
#      'hal_docid': '11141',
#      'country': 'France',
#      'ror': 'https://ror.org/04wez5e68',
#      'structId': '11141'},
#     {'detected_countries': ['fr'],
#      'name': 'Université Paris Nanterre, UPN, 200 avenue de la République - 92001 Nanterre cedex, France',
#      'hal_docid': '116205',
#      'country': 'France',
#      'ror': 'https://ror.org/013bkhk48',
#      'structId': '116205'},
#     {'detected_countries': ['fr'],
#      'name': 'Ministère de la Culture et de la Communication, MCC, 3, rue de Valois 75001 Paris, France',
#      'hal_docid': '300125',
#      'country': 'France',
#      'ror': 'https://ror.org/017rnyz40',
#      'structId': '300125'},
#     {'detected_countries': ['fr'],
#      'name': 'Centre National de la Recherche Scientifique, CNRS, France',
#      'hal_docid': '441569',
#      'country': 'France',
#      'ror': 'https://ror.org/02feahw73',
#      'structId': '441569'},
#     {'detected_countries': ['fr'],
#      'name': "Université Paris 1 Panthéon-Sorbonne - UFR Histoire de l'art et archéologie, UP1 UFR03, UP1, Université Paris 1 Panthéon-Sorbonne, 3 rue Michelet - 75006 Paris, France",
#      'hal_docid': '82480',
#      'country': 'France',
#      'structId': '82480'},
#     {'detected_countries': ['fr'],
#      'name': 'Université Paris 1 Panthéon-Sorbonne, UP1, 12 place du Panthéon, 75231 Paris Cedex 05, France',
#      'hal_docid': '7550',
#      'country': 'France',
#      'ror': 'https://ror.org/002t25c44',
#      'structId': '7550'},
#     {'detected_countries': ['fr'],
#      'name': "Ville de Chartres et Chartres Métropole - Direction de l'Archéologie, Direction Générale adjointe Aménagement et DéveloppementMairie de Chartres place des Halles 28019 Chartres, France",
#      'hal_docid': '1042627',
#      'country': 'France',
#      'structId': '1042627'}],
#    'author_position': 16,
#    'role': 'aut',
#    'datasource': 'hal'},
#   {'hal_docid': '648871-0',
#    'first_name': 'Céline',
#    'last_name': 'Villenave',
#    'full_name': 'Céline Villenave',
#    'affiliations': [{'detected_countries': ['fr'],
#      'name': "Institut national de recherches archéologiques préventives, Inrap, 121 rue d'Alésia75014 Paris, France",
#      'hal_docid': '301475',
#      'country': 'France',
#      'structId': '301475'}],
#    'author_position': 17,
#    'role': 'aut',
#    'datasource': 'hal'}],
#  'bso_classification': 'Humanities',
#  'bso_country': ['fr'],
#  'bso_country_corrected': ['fr'],
#  'bso_local_affiliations': ['7550',
#   'shs',
#   'univ-paris8',
#   'citeres',
#   '199318270',
#   'test5-halcnrs',
#   '205557',
#   '301475',
#   '1059646',
#   '11141',
#   'univ-paris10',
#   '178256',
#   '199947',
#   'univ-paris1',
#   'univ-paris-nanterre',
#   'inrap',
#   '82480',
#   'univ-tours',
#   '1041663',
#   '193708005',
#   '300125',
#   '1003',
#   'test3-halcnrs',
#   'univ-paris-lumieres',
#   'arscan',
#   'citeres-lat',
#   '259761',
#   'inee-cnrs',
#   '408770',
#   '421076',
#   '363687',
#   'mae',
#   'test-halcnrs',
#   'eveha',
#   'test4-halcnrs',
#   '441569',
#   '130018351',
#   '1042627',
#   '116205',
#   'cnrs',
#   '300298'],
#  'datasource': 'hal',
#  'external_ids': [{'id_type': 'hal_id', 'id_value': 'hal-03933378'}],
#  'genre': 'other',
#  'genre_raw': 'comm',
#  'hal_classification': [{'code': 'shs.archeo_',
#    'label': '_Humanities and Social Sciences/Archaeology and Prehistory'}],
#  'hal_collection_code': ['SHS',
#   'UNIV-PARIS1',
#   'INRAP',
#   'UNIV-PARIS8',
#   'UNIV-TOURS',
#   'CNRS',
#   'UNIV-PARIS10',
#   'CITERES-LAT',
#   'CITERES',
#   'MAE',
#   'ARSCAN',
#   'UNIV-PARIS-LUMIERES',
#   'TEST-HALCNRS',
#   'UNIV-PARIS-NANTERRE',
#   'TEST3-HALCNRS',
#   'TEST4-HALCNRS',
#   'EVEHA',
#   'TEST5-HALCNRS',
#   'INEE-CNRS'],
#  'hal_id': 'hal-03933378',
#  'has_doi_in_hal': 0.0,
#  'has_grant': 0.0,
#  'id': 'halhal-03933378',
#  'id_type': 'hal',
#  'keywords': [{'keyword': 'Sépulture'},
#   {'keyword': 'Inhumation'},
#   {'keyword': 'Centre-Val de Loire'}],
#  'natural_id': 'f8f5d55c1bafa6553b6502f859b457e1',
#  'published_date': '2019-06-03T00:00:00',
#  'publisher_dissemination': 'unknown',
#  'publisher_group': 'unknown',
#  'publisher_normalized': 'unknown',
#  'random': 0.003195159764768,
#  'rors': ['https://ror.org/04wez5e68',
#   'https://ror.org/02wwzvj46',
#   'https://ror.org/057qpr032'],
#  'sources': ['HAL'],
#  'title': 'Typo-chronologie des tombes à inhumation en région Centre-Val de Loire et dans le département du Maine-et-Loire',
#  'year': 2019,
#  'lang': 'fr',
#  'publisher_in_bealls_list': False,
#  'journal_or_publisher_in_bealls_list': False,
#  'oa_details': {'2024Q4': {'is_oa': False,
#    'snapshot_date': '20241201',
#    'observation_date': '2024Q4',
#    'oa_host_type': 'closed',
#    'oa_colors': ['closed'],
#    'oa_colors_with_priority_to_publisher': ['closed'],
#    'repositories_concat': 'closed',
#    'is_oa_hal': False},
#   '2023Q4': {'is_oa': False,
#    'snapshot_date': '20231214',
#    'observation_date': '2023Q4',
#    'oa_host_type': 'closed',
#    'oa_colors': ['closed'],
#    'oa_colors_with_priority_to_publisher': ['closed'],
#    'repositories_concat': 'closed',
#    'is_oa_hal': False}},
#  'is_defended': False,
#  'has_hal_id': True,
#  'has_crossref': False,
#  'has_fr_corresponding': False,
#  'affiliations': [{'detected_countries': ['fr'],
#    'name': "Institut national de recherches archéologiques préventives, Inrap, 121 rue d'Alésia75014 Paris, France",
#    'hal_docid': '301475',
#    'structId': '301475',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': "De la Préhistoire à l'Actuel : Culture, Environnement et Anthropologie, UMR5199, PACEA, UB, CNRS, Université de Bordeaux, Centre National de la Recherche Scientifique, Université de Bordeaux - Bâtiment B8 - CS50023 - Allée Geoffroy-Saint-Hilaire - 33615 Pessac Cedex, France",
#    'hal_docid': '205557',
#    'rnsr': '200411870P',
#    'ror': 'https://ror.org/027mnq498',
#    'structId': '205557',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': 'Université de Bordeaux, UB, 35, place Pey Berland - 33076 Bordeaux, France',
#    'hal_docid': '259761',
#    'ror': 'https://ror.org/057qpr032',
#    'structId': '259761',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': 'Centre National de la Recherche Scientifique, CNRS, France',
#    'hal_docid': '441569',
#    'ror': 'https://ror.org/02feahw73',
#    'structId': '441569',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': 'Cités, Territoires, Environnement et Sociétés, UMR 7324, UMR7324 / UMR6173, CITERES, UT, CNRS, Université de Tours, Centre National de la Recherche Scientifique, 33 allée Ferdinand de Lesseps BP 60449 37204 Tours cedex 3, France',
#    'hal_docid': '199947',
#    'rnsr': '201220233V',
#    'ror': 'https://ror.org/04ahza989',
#    'structId': '199947',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': "Université de Tours, UT, 60 rue du Plat d'Étain, 37020 Tours cedex 1, France",
#    'hal_docid': '300298',
#    'ror': 'https://ror.org/02wwzvj46',
#    'structId': '300298',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': "Service de l'archéologie du département d'Indre-et-Loire, SADIL, Conseil général d'Indre-et-Loire, Hôtel du Département, Place de la Préfecture, 37927 Tours Cedex 9, France",
#    'hal_docid': '408770',
#    'structId': '408770',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': 'EVEHA (Etudes et valorisations archeologiques), 31 rue Soyouz - ESTER Technopole87 068 LIMOGES CedexTel : 05 55 10 98 72contact@eveha.fr, France',
#    'hal_docid': '363687',
#    'structId': '363687',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': "Service Archéologique Municipal d'Orléans, 13 bis rue de la Tour Neuve45000 Orléans, France",
#    'hal_docid': '421076',
#    'structId': '421076',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': "Service d'archéologie préventive de Bourges Plus, MCC, Ministère de la Culture et de la Communication, France",
#    'hal_docid': '178256',
#    'structId': '178256',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': 'Ministère de la Culture et de la Communication, MCC, 3, rue de Valois 75001 Paris, France',
#    'hal_docid': '300125',
#    'ror': 'https://ror.org/017rnyz40',
#    'structId': '300125',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': 'Département de Maine-et-Loire - Pôle archéologie, 108 Rue de Frémur, 49000 Angers, France',
#    'hal_docid': '1041663',
#    'structId': '1041663',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': "Archéologies et Sciences de l'Antiquité, UMR7041, UMR7041, UMR7041, UMR7041, ArScAn, UP1, UP8, UPN, MCC, CNRS, Université Paris 1 Panthéon-Sorbonne, Université Paris 8 Vincennes-Saint-Denis, Université Paris Nanterre, Ministère de la Culture et de la Communication, Centre National de la Recherche Scientifique, MSH Mondes (bâtiment René-Ginouvès). 21, allée de l’Université 92023 NANTERRE Cedex, France",
#    'hal_docid': '1003',
#    'rnsr': '199912442H',
#    'ror': 'https://ror.org/04wz9m339',
#    'structId': '1003',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': 'Université Paris 1 Panthéon-Sorbonne, UP1, 12 place du Panthéon, 75231 Paris Cedex 05, France',
#    'hal_docid': '7550',
#    'ror': 'https://ror.org/002t25c44',
#    'structId': '7550',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': 'Université Paris 8 Vincennes-Saint-Denis, UP8, 2 rue de la Liberté - 93526 Saint-Denis cedex, France',
#    'hal_docid': '11141',
#    'ror': 'https://ror.org/04wez5e68',
#    'structId': '11141',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': 'Université Paris Nanterre, UPN, 200 avenue de la République - 92001 Nanterre cedex, France',
#    'hal_docid': '116205',
#    'ror': 'https://ror.org/013bkhk48',
#    'structId': '116205',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': "TranSphères, ArScAn, Archéologies et Sciences de l'Antiquité, MSH Mondes (bâtiment René-Ginouvès). 21, allée de l’Université 92023 NANTERRE Cedex, France",
#    'hal_docid': '1059646',
#    'structId': '1059646',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': "Université Paris 1 Panthéon-Sorbonne - UFR Histoire de l'art et archéologie, UP1 UFR03, UP1, Université Paris 1 Panthéon-Sorbonne, 3 rue Michelet - 75006 Paris, France",
#    'hal_docid': '82480',
#    'structId': '82480',
#    'datasource': 'hal'},
#   {'detected_countries': ['fr'],
#    'name': "Ville de Chartres et Chartres Métropole - Direction de l'Archéologie, Direction Générale adjointe Aménagement et DéveloppementMairie de Chartres place des Halles 28019 Chartres, France",
#    'hal_docid': '1042627',
#    'structId': '1042627',
#    'datasource': 'hal'}],
#  'french_affiliations_types': ['cnrs', 'university'],
#  'author_useful_rank_fr': True,
#  'openalex_id': 'W3184620536',
#  'cited_by_count': 0.0,
#  'hal_struct_id': [301475,
#   205557,
#   259761,
#   441569,
#   199947,
#   300298,
#   441569,
#   408770,
#   363687,
#   421076,
#   178256,
#   300125,
#   1041663,
#   1003,
#   7550,
#   11141,
#   116205,
#   300125,
#   441569,
#   1059646,
#   1003,
#   7550,
#   11141,
#   116205,
#   300125,
#   441569,
#   82480,
#   7550,
#   1042627],
#  'detected_countries': ['fr'],
#  'hal_docType': 'COMM',
#  'author_useful_rank_countries': ['fr']}

# %%
re.match('hal', 'hal-1')
# Out:
# <re.Match object; span=(0, 3), match='hal'>

# %%
authors_halid_s = []
authors_halid_i = []
authors_fullname = []
authors_orcid = []
structures_id = []
structures_country = []
hal_class_code = []
bso_class = []
pub_year = []
pub_date = []
pub_type = []
pub_hal_id = []
is_oa = []
list_ids = []

for n, x in enumerate(list_id_pub):
    
    dict_pub = datas[n]
    if 'authors' in dict_pub:
        #print(n, x)
        list_author = []
        list_author_id_s = []
        list_author_id_i = []
        list_author_orcid = []
        list_structures_id = []
        list_country = []
        list_keyword = []
        list_ids.append(x)
        
        for a in dict_pub['authors']:
            #print(a)
            
            if  'full_name' in a:
                list_author.append(a['full_name'])
            else:
                list_author.append('no full_name')
            if 'id_hal_s' in a:
                list_author_id_s.append(a['id_hal_s'])
            else:
                list_author_id_s.append('no_id_hal_s')
            if 'id_hal_i'  in a:
                list_author_id_i.append(a['id_hal_i'])
            else:
                list_author_id_i.append('no_id_hal_i')
            if 'orcid' in a:
                list_author_orcid.append(a['orcid'])
            else:
                list_author_orcid.append('no orcid')
            if "affiliations" in a:
                for affil in a["affiliations"][0]:
                    print(affil)
    
        authors_halid_s.append("|".join(list_author_id_s))
        authors_halid_i.append("|".join(list_author_id_i))
        authors_fullname.append("|".join(list_author))
        authors_orcid.append("|".join(list_author_orcid))
        #structures_country.append("|".join(list_country))

        if 'hal' in x:
            pub_hal_id.append(x[3:])
        else:
            pub_hal_id.append(np.nan)
        if 'hal_classification' in dict_pub:
            hal_classification = [h['code'] for h in dict_pub['hal_classification']]
            hal_class_code.append('|'.join(hal_classification))
        else:
            hal_class_code.append('no hal_classification')
        bso_class.append(dict_pub['bso_classification'])
        if 'keywords' in dict_pub:
            for kw in dict_pub["keywords"]:
                list_keyword.append(kw["keyword"])
        else:
            list_keyword.append('no keywords')
        affiliations_i = [inst for inst in dict_pub['bso_local_affiliations']  if re.search(r'[a-z]', inst) is None ]
        structures_id.append('|'.join(affiliations_i))
        pub_type.append(dict_pub['genre'])
        #pub_date.append(dict_pub['published_date'])
        pub_year.append(dict_pub['year'])

        for y in dict_pub['oa_details']:
            if y == "2024Q4":
                dict_oa = dict_pub['oa_details'][y]
                #published_date.append(dict_pub['external_ids']['published_date'])
                is_oa.append(dict_oa["is_oa"])
    else:
        pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 51
#      49     if "affiliations" in a:
#      50         for affil in a["affiliations"][0]:
# ---> 51             for country in affil["country"]:
#      52                 list_country.append(country)
#      54 authors_halid_s.append("|".join(list_author_id_s))
#
# TypeError: string indices must be integers, not 'str'

# %%
data_columns = {
    "id": list_ids,
    'hal_id': pub_hal_id,
    "pub_year" : pub_year,
    'authors' : authors_fullname,
    'authhalid_s': authors_halid_s,
    'authhalid_i':authors_halid_i,
    'orcid': authors_orcid,
    'struchal_id': structures_id,
    'struc_country': structures_country,
    'hal_classif' : hal_class_code,
    'bso_classif' : bso_class,
    'pub_type': pub_type,
    'is_oa': is_oa
}

df0 = pd.DataFrame(data= data_columns)

# %%
df0.to_csv("../Data/outputs/2026-01-23_list_of_publi_from_bso.csv", sep = ",", index = False)

# %%
df0
# Out:
#                               id        hal_id  pub_year  \
# 0                halhal-03933378  hal-03933378      2019
# 1                halhal-03895949  hal-03895949      2017
# 2                halhal-01789653  hal-01789653      2017
# 3                halhal-03807832  hal-03807832      2014
# 4      doi10.3917/cliop.028.0029           NaN      2022
# ...                          ...           ...       ...
# 48081            halhal-04095338  hal-04095338      2020
# 48082            halhal-03299923  hal-03299923      2020
# 48083            halhal-04366816  hal-04366816      2023
# 48084            halhal-02120667  hal-02120667      2018
# 48085            halhal-01964707  hal-01964707      2020
#
#                                                  authors  \
# 0      Jérôme Livet|François Capron|Philippe Blanchar...
# 1                           Katerina Chryssanthaki-Nagle
# 2                                          Makis Solomos
# 3                                        Isabelle Launay
# 4      Léandro de Lajonquière|Floriana Baldassi D’Arrigo
# ...                                                  ...
# 48081                                     Céline Clément
# 48082                                    Martine Créac'H
# 48083  Brigitte Bardin|Anne Burguet|Sophie Henry|Nico...
# 48084  Valentina M. Azzarà|A.P. de Rorre|Jean-Francoi...
# 48085                                    Coralie Vincent
#
#                                              authhalid_s  \
# 0      jerome-livet|francois-capron|philippe-blanchar...
# 1                                            no_id_hal_s
# 2                                            no_id_hal_s
# 3                                            no_id_hal_s
# 4                                no_id_hal_s|no_id_hal_s
# ...                                                  ...
# 48081                            celine-clement-nanterre
# 48082                                     martine-creach
# 48083  brigitte-bardin|annette-burguet|sophie-henry|n...
# 48084  no_id_hal_s|no_id_hal_s|jean-francois-berger|g...
# 48085                                           cvincent
#
#                                              authhalid_i  \
# 0      176081|15426|18849|245|6836|2483|no_id_hal_i|1...
# 1                                            no_id_hal_i
# 2                                            no_id_hal_i
# 3                                            no_id_hal_i
# 4                                no_id_hal_i|no_id_hal_i
# ...                                                  ...
# 48081                                            1253116
# 48082                                             746578
# 48083                     1316897|753990|1327258|1268072
# 48084               no_id_hal_i|no_id_hal_i|742611|13749
# 48085                                               4552
#
#                                                    orcid  \
# 0      0000-0002-1785-776X|no orcid|0000-0003-0829-77...
# 1                                               no orcid
# 2                                               no orcid
# 3                                               no orcid
# 4                                      no orcid|no orcid
# ...                                                  ...
# 48081                                           no orcid
# 48082                                           no orcid
# 48083  no orcid|0009-0005-8979-2706|no orcid|0000-000...
# 48084  no orcid|no orcid|0000-0002-4360-7262|0000-000...
# 48085                                           no orcid
#
#                                              struchal_id  \
# 0      7550|199318270|205557|301475|1059646|11141|178...
# 1      7550|199318270|11141|300125|1003|441569|105964...
# 2                                 199318270|11141|188359
# 3                                 199318270|11141|188359
# 4                199318270|199411117|420786|106111|11141
# ...                                                  ...
# 48081        439352|441569|199318270|116205|443665|11141
# 48082                            199318270|1007102|11141
# 48083  199318270|193113842|217752|1052984|11141|42812...
# 48084  7550|199318270|301232|11141|300311|196901920|1...
# 48085               441569|199318270|204862|475360|11141
#
#                                              hal_classif  \
# 0                                            shs.archeo_
# 1      shs.archeo_|shs.art_|shs.class_|shs.hist_|shs....
# 2                                             shs.musiq_
# 3                                        shs_|shs.musiq_
# 4                                      shs.edu_|shs.psy_
# ...                                                  ...
# 48081                               shs.demo_|shs.socio_
# 48082                                     shs_|shs.litt_
# 48083                                         scco.psyc_
# 48084                    shs.archeo_|sde.es_|sdu.stu.gp_
# 48085    spi.signal_|info.info-ts_|shs.musiq_|scco.ling_
#
#                                         bso_classif         pub_type  is_oa
# 0                                        Humanities            other  False
# 1                                        Humanities      proceedings  False
# 2                                        Humanities  journal-article   True
# 3                                        Humanities     book-chapter  False
# 4                                   Social sciences  journal-article  False
# ...                                             ...              ...    ...
# 48081                               Social sciences            other  False
# 48082                                    Humanities  journal-article  False
# 48083                                    Humanities            other   True
# 48084  Earth, Ecology, \nEnergy and applied biology            other  False
# 48085                                    Humanities     book-chapter   True
#
# [48086 rows x 12 columns]

# %%
import hal_extractor

# %%
list_idhal = hal_extractor.get_list_idhal("../Data/outputs/2026-01-23_list_of_publi_from_bso.csv",  column = 'authhalid_i')
list_idhal2 = [x for x in list_idhal if re.search(r'[a-z]',x) is None]
len(list_idhal2)
# Out:
# nombre d'identifiant :  5899
# 5898

# %%
url_api_search = "https://api.archives-ouvertes.fr/ref/author/"


params = {
    "q":f"idHal_i:965723", #la clé de recherche. On peut envisager de faire une recherche sur d'autre champs
    "wt":"json", #Le format de sortie, ici json
    "fl" : "idHal_i,idHal_s,lastName_s,firstName_s,affPref_i,accountAssociated_bool,form_i,hasCV_bool", #La liste des champs obtenues
    "rows" : 1} # le nombre de ligne. Par défaut, l'api affiche les 30 première ligne et le maximum fixé est de 10000.

# %%
hal_extractor.try_get_answer(url_api_search, params).json()
# Out:
# {'response': {'numFound': 1,
#   'start': 0,
#   'numFoundExact': True,
#   'docs': [{'form_i': 907732,
#     'firstName_s': 'Aymeric',
#     'lastName_s': 'Luneau',
#     'idHal_i': 965723,
#     'idHal_s': 'aymeric-luneau',
#     'hasCV_bool': True,
#     'accountAssociated_bool': True,
#     'affPref_i': [394361]}]}}

# %%
path_folder = hal_extractor.create_folder(ref= "auteur", year=2026)
print(path_folder)
for n, idhal in tqdm.tqdm(enumerate(list_idhal2), total = len(list_idhal)):
    params["q"]= f"idHal_i:{idhal}"
    reponse = hal_extractor.try_get_answer(url_api_search, params).json()
    list_row = hal_extractor.process_json_to_csv(reponse,  params,  ref = "auteur", path_folder=path_folder)
# Out:
# ../Data/raw/auteur/2026
#   1%|▊                                                                            | 65/5899 [00:08<13:35,  7.15it/s]

# %%
list_idhal = hal_extractor.get_list_idhal("../Data/raw/auteur/2025/hal_auteur.csv", column = 'affPref_i')
# Out:
# nombre d'identifiant :  2316

# %%
url_api_search = "https://api.archives-ouvertes.fr/ref/structure/"


params = {
    "q":f"docid:11141", #la clé de recherche. On peut envisager de faire une recherche sur d'autre champs
    "wt":"json", #Le format de sortie, ici json
    "fl" : "docid,name_s,type_s,acronym_s,country_s,parentAcronym_s,parentDocid_i,parentName_s,parentType_s", #La liste des champs obtenues
    "rows" : 1} # le nombre de ligne. Par défaut, l'api affiche les 30 première ligne et le maximum fixé est de 10000.
for y in dict_pub['oa_details']:
        dict_oa = dict_pub['oa_details'][y]
        list_ids.append(x)
        #published_date.append(dict_pub['external_ids']['published_date'])
        pub_year.append(str(dict_pub['year']))
        is_oa.append(dict_oa["is_oa"])

hal_extractor.try_get_answer(url_api_search, params).json()
# Out:
# {'response': {'numFound': 1,
#   'start': 0,
#   'numFoundExact': True,
#   'docs': [{'docid': '11141',
#     'name_s': 'Université Paris 8',
#     'acronym_s': 'UP8',
#     'country_s': 'fr',
#     'type_s': 'institution'}]}}

# %%
path_folder = hal_extractor.create_folder(ref = "structure", year = 2026)
for n, idhal in tqdm.tqdm(enumerate(list_idhal), total = len(list_idhal)):
    params["q"]= f"docid:{idhal}"
    reponse = requests.get(url_api_search, params).json()
    #print(reponse)
    list_row = hal_extractor.process_json_to_csv(reponse, params, ref = "structure", path_folder = path_folder)
# Out:
# 100%|███████████████████████████████████████| 2316/2316 [05:45<00:00,  6.70it/s]

# %% [markdown]
# # Create liste of edges

# %%
#df = pd.read_csv("/home/aymeric/paris8/barometre_scienceouverte_universitedelorraine/Data/outputs/20250507_hal_univ_paris8.csv", sep =",") # contient les publications
dfs = pd.read_csv("../Data/raw/structure/2026/hal_structure.csv", sep =",", dtype={"docid":str}) # Contient les structures
dfa = pd.read_csv("../Data/raw/auteur/2025/hal_auteur.csv", sep =",", dtype={"idHal_i":str}) # Contient les auteurs
df0.loc[df0.authhalid_s.str.contains("luneau")]
dfs.country_s.value_counts()
# Out:
# country_s
# fr    1928
# ch      17
# es      13
# it      12
# gb      11
# be       9
# de       9
# ca       9
# re       8
# br       7
# tn       6
# us       5
# cl       4
# za       4
# eg       3
# gr       3
# pt       3
# ma       3
# nc       3
# il       3
# sn       3
# at       3
# nl       3
# lb       2
# dz       2
# jp       2
# ec       2
# pf       2
# pe       2
# pl       2
# tw       1
# ae       1
# mq       1
# ye       1
# ru       1
# cy       1
# ci       1
# om       1
# la       1
# ht       1
# mx       1
# lt       1
# BE       1
# in       1
# gp       1
# et       1
# cz       1
# uy       1
# gf       1
# ie       1
# tr       1
# ga       1
# co       1
# cn       1
# th       1
# sg       1
# au       1
# Name: count, dtype: int64

# %%
dfa['docid'] = dfa.affPref_i.str.split("|") #docid correspond au nom de la colonne contenant les id des structures dans dfs
dfa1 = dfa.explode("docid")
dfa2 = dfa1[['idHal_i', 'idHal_s','docid']].dropna()

dfas0 = dfa2.merge(dfs, on = ["docid"], how = "left")
dfas = dfas0.loc[~dfas0.name_s.isna()].rename(columns={"idHal_i":"id"})
dfas["struct_id"] = dfas["docid"] +"_str"
dfas["author_id"] = dfas["id"] +"_au"

# %%
df.loc[df.idHal_s.str.lower().str.contains("luneau")]

# %% [markdown]
# On "explose" le dataframe concernant les publi pour avoir une ligne par co-auteur. permets de faire ensuite la liste des edges

# %%
df["author_id"] = df.authIdHal_i.str.split("|")
df1 = df.explode("author_id")



liste_halid_i = [x for x in df1[["author_id"]].author_id.drop_duplicates() if x is not np.nan]
df2 = df1[["halId_s", "author_id"]].dropna().sort_values("halId_s")
df2["author_id"] = df2["author_id"] +"_au"
df2.loc[df2.author_id=="965723_au"]

# %%
df.loc[df.authFullName_s.str.contains("Luneau")]

# %%
dfalab = dfas.loc[dfas.type_s=="laboratory"].rename(columns={"docid":"labhal_id",'acronym_s':'lab_acronym',"name_s":"lab_name"})#.dropna()
dfauniv = dfas.loc[dfas.type_s=="institution"].rename(columns={"docid":"instithal_id",'acronym_s':'instit_acronym', "name_s":"instit_name"})#.dropna()
dfas.loc[dfas.author_id=="965723_au"]
#df2b.loc[~(df2b.id.isna())|~(df2b.idHal_s.isna())]

# %%
df2b = df2.merge(dfalab, on =["author_id"], how ="left").dropna()

# %%
df2b

# %%
dict_openaccess = dict(zip(df.halId_s, df.openAccess_bool))
df2["is_oa"] = df2.halId_s.map(dict_openaccess.get)
freq_oa = df2.groupby(["author_id","is_oa"]).agg(nb=("halId_s", "size" )).reset_index()
freq_total = df2.groupby(["author_id"]).agg(total=("halId_s", "size" )).reset_index()
freq_oa =freq_oa.merge(freq_total, on = ["author_id"], how = "left")
freq_oa["ratio_oa"] = (freq_oa.nb / freq_oa.total)
freq_oa["log_ratio_oa"] = np.log(1 + freq_oa.nb)
freq_oa["log_ratio_oa1"] = freq_oa["log_ratio_oa"].astype(int)
freq_oa["log_ratio_oa2"] = freq_oa["log_ratio_oa"].round(1)#astype(int)

dict_freq_oa = dict(zip(freq_oa.author_id.loc[freq_oa.is_oa==True], freq_oa.nb.loc[freq_oa.is_oa==True]))
dict_total = dict(zip(freq_oa.author_id.loc[freq_oa.is_oa==True], freq_oa.total.loc[freq_oa.is_oa==True]))
dict_ratio_oa = dict(zip(freq_oa.author_id.loc[freq_oa.is_oa==True], freq_oa.ratio_oa.loc[freq_oa.is_oa==True]))
dict_log_oa = dict(zip(freq_oa.author_id.loc[freq_oa.is_oa==True], freq_oa.log_ratio_oa.loc[freq_oa.is_oa==True]))
dict_log_oa2 = dict(zip(freq_oa.author_id.loc[freq_oa.is_oa==True], freq_oa.log_ratio_oa1.loc[freq_oa.is_oa==True]))
dict_log_oa3 = dict(zip(freq_oa.author_id.loc[freq_oa.is_oa==True], freq_oa.log_ratio_oa2.loc[freq_oa.is_oa==True]))
freq_oa

# %%
df_halid = df2b[["halId_s"]].rename(columns={"halId_s":"id"}).drop_duplicates()
df_halid["Type"] = "publi"
df_auth= df2b[["author_id","idHal_s","lab_acronym","parentAcronym_s", "parentName_s"]].drop_duplicates("author_id").rename(columns={"author_id":"id"})
df_auth["Type"] = "auteur"
df_auth["nb_oa"] = df_auth.id.map(dict_freq_oa.get)
df_auth["ratio_oa"] = df_auth.id.map(dict_ratio_oa.get)
df_auth["log_ratio_oa"] = df_auth.id.map(dict_log_oa.get)
df_auth["log_ratio_oa1"] = df_auth.id.map(dict_log_oa2.get)
df_auth["log_ratio_oa2"] = df_auth.id.map(dict_log_oa3.get)
df_auth["total"] = df_auth.id.map(dict_total.get)
df_auth = df_auth.fillna(0)

# %% [markdown]
# ## Rattachement institutionnel des labos à P8
#
# for

# %%
"parentAcronym_s", "parentName_s"
df_auth.loc[df_auth.parentAcronym_s.str.lower().str.contains("up8") == True, "is_P8"] = True
df_auth.loc[df_auth.parentAcronym_s.str.lower().str.contains("up8") == False, "is_P8"] = False

nodes = pd.concat([df_halid, df_auth])
nodes

# %% [markdown]
# # Graphe Auteur-Publi

# %%
G = nx.Graph()
G.add_nodes_from(df2b.halId_s, part="publi")
G.add_nodes_from(df2b.author_id, part="auteur")
G.add_edges_from(df2b[["halId_s", "author_id"]].values)

# %%
nodes["Label"] = nodes["id"]
node_attr = nodes.set_index('id').to_dict('index')
nx.set_node_attributes(G, node_attr)

# %%
Sigma(G, node_color="is_P8")

# %%
monoG = pelote.monopartite_projection(G, 'auteur')
nx.number_of_nodes(monoG)
nx.number_connected_components(monoG)

df_auth["Label"] = df_auth["id"]
node_attr = df_auth.set_index('id').to_dict('index')
nx.set_node_attributes(monoG, node_attr)

# %%
degres = nx.degree_centrality(monoG)

not_normalized_degres = {}

for x in degres :
    not_normalized_degres[x] = degres[x] * (nx.number_of_nodes(monoG)-1)


nx.set_node_attributes(monoG, degres, 'normalized_degres')
nx.set_node_attributes(monoG, not_normalized_degres, 'degres')
#h = pelote.filter_nodes(monoG, lambda n, a: a["degres"] > 2)
#pelote.crop_to_largest_connected_component(monoG)
print(nx.number_connected_components(monoG))
louv_communities = nx.community.louvain_communities(monoG)

community={}

print(len(louv_communities))
for n, x in enumerate(louv_communities):
    #print(n)
    for name in x:
        community[name] = n

nx.set_node_attributes(monoG, community, 'community')

# %%
Sigma(monoG, node_label='idHal_s', node_color= "is_P8", node_shape="type_node", node_size="nb_oa")

# %% [markdown]
# # Graphe Publi-labo

# %%
df2bb = df2b[["halId_s","labhal_id", "lab_acronym","parentAcronym_s", "parentName_s"]].drop_duplicates()
G = nx.Graph()
G.add_nodes_from(df2bb.halId_s, part="publi")
G.add_nodes_from(df2bb.labhal_id, part="labos")
G.add_edges_from(df2b[["halId_s", "labhal_id"]].values)

# %%
dict_openaccess = dict(zip(df.halId_s, df.openAccess_bool))
df2bb["is_oa"] = df2bb.halId_s.map(dict_openaccess.get)
freq_oa = df2bb.groupby(["labhal_id","is_oa"]).agg(nb=("labhal_id", "size" )).reset_index()
freq_total = df2bb.groupby(["labhal_id"]).agg(total=("labhal_id", "size" )).reset_index()
freq_oa =freq_oa.merge(freq_total, on = ["labhal_id"], how = "left")
freq_oa["ratio_oa"] = (freq_oa.nb / freq_oa.total)
freq_oa["log_ratio_oa"] = np.log(1 + freq_oa.nb)
freq_oa["log_ratio_oa1"] = freq_oa["log_ratio_oa"].astype(int)
freq_oa["log_ratio_oa2"] = freq_oa["log_ratio_oa"].round(1)#astype(int)

dict_freq_oa = dict(zip(freq_oa.labhal_id.loc[freq_oa.is_oa==True], freq_oa.nb.loc[freq_oa.is_oa==True]))
dict_total = dict(zip(freq_oa.labhal_id.loc[freq_oa.is_oa==True], freq_oa.total.loc[freq_oa.is_oa==True]))
dict_ratio_oa = dict(zip(freq_oa.labhal_id.loc[freq_oa.is_oa==True], freq_oa.ratio_oa.loc[freq_oa.is_oa==True]))
dict_log_oa = dict(zip(freq_oa.labhal_id.loc[freq_oa.is_oa==True], freq_oa.log_ratio_oa.loc[freq_oa.is_oa==True]))
dict_log_oa2 = dict(zip(freq_oa.labhal_id.loc[freq_oa.is_oa==True], freq_oa.log_ratio_oa1.loc[freq_oa.is_oa==True]))
dict_log_oa3 = dict(zip(freq_oa.labhal_id.loc[freq_oa.is_oa==True], freq_oa.log_ratio_oa2.loc[freq_oa.is_oa==True]))
freq_oa

# %%
df_halid = df2bb[["halId_s"]].rename(columns={"halId_s":"id"}).drop_duplicates()
df_halid["Type"] = "publi"
df_auth= df2bb[["labhal_id", "lab_acronym","parentAcronym_s", "parentName_s"]].drop_duplicates().rename(columns={"labhal_id":"id"})
df_auth["Type"] = "labos"

df_auth.loc[df_auth.parentAcronym_s.str.lower().str.contains("up8") == True, "is_P8"] = True
df_auth.loc[df_auth.parentAcronym_s.str.lower().str.contains("up8") == False, "is_P8"] = False


df_auth["nb_oa"] = df_auth.id.map(dict_freq_oa.get)
df_auth["ratio_oa"] = df_auth.id.map(dict_ratio_oa.get)
df_auth["log_ratio_oa"] = df_auth.id.map(dict_log_oa.get)
df_auth["log_ratio_oa1"] = df_auth.id.map(dict_log_oa2.get)
df_auth["log_ratio_oa2"] = df_auth.id.map(dict_log_oa3.get)
df_auth["total"] = df_auth.id.map(dict_total.get)

nodes = pd.concat([df_halid, df_auth])
df_auth

# %%
nodes["Label"] = nodes["id"]
node_attr = nodes.set_index('id').to_dict('index')
nx.set_node_attributes(G, node_attr)

# %%
monoG = pelote.monopartite_projection(G, 'labos')
nx.number_of_nodes(monoG)
nx.number_connected_components(monoG)

df_auth["Label"] = df_auth["id"]
node_attr = df_auth.set_index('id').to_dict('index')
nx.set_node_attributes(monoG, node_attr)

# %%
degres = nx.degree_centrality(monoG)

not_normalized_degres = {}

for x in degres :
    not_normalized_degres[x] = degres[x] * (nx.number_of_nodes(monoG)-1)


nx.set_node_attributes(monoG, degres, 'normalized_degres')
nx.set_node_attributes(monoG, not_normalized_degres, 'degres')
#h = pelote.filter_nodes(monoG, lambda n, a: a["degres"] > 2)
pelote.crop_to_largest_connected_component(monoG)
print(nx.number_connected_components(monoG))
louv_communities = nx.community.louvain_communities(monoG)

community={}

print(len(louv_communities))
for n, x in enumerate(louv_communities):
    #print(n)
    for name in x:
        community[name] = n

nx.set_node_attributes(monoG, community, 'community')

# %%
Sigma(monoG, node_label='lab_acronym', node_color= "is_P8", node_shape="Type", node_size="nb_oa")

# %% [markdown]
# ## Graphe auteur et institution

# %%
dfasb = dfas.loc[(dfas.type_s=="laboratory")]
dfasb.loc[(dfasb.acronym_s.isna()), "acronym"] = dfasb.docid
dfasb.loc[~(dfasb.acronym_s.isna()), "acronym"] = dfasb.acronym_s
dfasb.loc[(dfasb.idHal_s.isna()), "idHal"] = dfasb.id
dfasb.loc[~(dfasb.idHal_s.isna()), "idHal"] = dfasb.idHal_s
dfas_str = dfasb[["acronym","type_s"]].rename(columns={"acronym":"nom"}).drop_duplicates()

dfas_str["Type"] = "structure"
dfas_au= dfasb[["idHal"]].rename(columns={"idHal":"nom"}).drop_duplicates()

dfas_au["Type"] = "chercheur"
dfas_au["type_s"] = "chercheur"
nodes = pd.concat([dfas_au, dfas_str]).dropna()
nodes
#nodes = nodes0.merge(dfalab[['id', 'idHal_s', 'labhal_id', 'lab_name','lab_acronym']], on =["id"], how ="left")#.merge(dfauniv[['id', 'instithal_id', 'instit_name',
       #'instit_acronym']], on =["id"], how ="left")
#nodes = nodes0.merge(dfauniv[['id', 'idHal_s','instithal_id', 'instit_name', 'instit_acronym']], on =["id"], how ="left")
l = [x for x in dfasb.idHal if isinstance(x, float)==True]
nodes

# %%
G = nx.Graph()
G.add_nodes_from(dfasb.acronym, part="structure")
G.add_nodes_from(dfasb.idHal, part="chercheur")
G.add_edges_from(dfasb[["idHal", "acronym"]].values)

# %%
nodes["Label"] = nodes["nom"]
node_attr = nodes.set_index('nom').to_dict('index')
nx.set_node_attributes(G, node_attr)

# %%
monoG = pelote.monopartite_projection(G, 'chercheur')
nx.number_of_nodes(monoG)
nx.number_connected_components(monoG)

# %%
degres = nx.degree_centrality(monoG)

not_normalized_degres = {}

for x in degres :
    not_normalized_degres[x] = degres[x] * (nx.number_of_nodes(monoG)-1)


nx.set_node_attributes(monoG, degres, 'normalized_degres')
nx.set_node_attributes(monoG, not_normalized_degres, 'degres')
#h = pelote.filter_nodes(monoG, lambda n, a: a["degres"] > 2)
#pelote.crop_to_largest_connected_component(monoG)
print(nx.number_connected_components(monoG))
louv_communities = nx.community.louvain_communities(monoG)

community={}

print(len(louv_communities))
for n, x in enumerate(louv_communities):
    #print(n)
    for name in x:
        community[name] = n

nx.set_node_attributes(monoG, community, 'community')

# %%
Sigma(monoG, node_label="Label", node_color= "community", node_shape="type_s", node_size="degres")
