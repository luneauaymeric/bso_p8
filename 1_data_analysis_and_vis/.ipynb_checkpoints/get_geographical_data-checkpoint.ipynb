# %% [markdown]
# # Récupérer les données géographiques (pays, villes)

# %%
#chargement des modules
import pandas as pd
import datetime
import os
import json
from io import StringIO
import numpy as np
import plotly.express as px
import re

# %%
import s3fs #pour connecter au bucket

# %%
# Create filesystem object
S3_ENDPOINT_URL = "https://" + os.environ["AWS_S3_ENDPOINT"]
fs = s3fs.S3FileSystem(client_kwargs={'endpoint_url': S3_ENDPOINT_URL})

BUCKET_OUT = "aluneau"

# %%
file_path = BUCKET_OUT + "/" + "Data_bso/fichier_from_mesr/bso-publications-latest_199318270_enriched.jsonl"
print(file_path)
list_id_pub = []
datas =[]
with fs.open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        try:
            data = json.loads(line)
            # Extract specific fields
            ids = data.get('all_ids')
            list_id_pub.append(ids[0])
            datas.append(data)
            
        except json.JSONDecodeError:
            continue  # Skip invalid lines
# Out:
# aluneau/Data_bso/fichier_from_mesr/bso-publications-latest_199318270_enriched.jsonl

# %% [markdown]
# La cellule ci-dessous récupèrent les données qui nous intéressent depuis le fichier Json. Ces données seront ensuitre structurées dans un dataframe constitué d'une ligne par publication.
#
# **Remarque** : Il est probable que les données soient déjà disponibles dans le fichier "bso-publications-latest_199318270_enriched.csv".

# %%
authors_halid_s = [] #identifiant HAl au format string : prenom.nom
authors_halid_i = [] # identifiant hal au format numerique, ex: 191919
authors_fullname = [] #nom prénom de l'auteur
authors_orcid = [] #orcid de l'auteur
structures_id = [] #hal id de la structure
structures_country = [] #pays de la structurre (si plusieurs structures, on prend la première dans l'ordre d'apparition)
structures_address = [] #addresse de la structurre (si plusieurs structures, on prend la première dans l'ordre d'apparition)
hal_class_code = [] #Classification hal
bso_class = [] #Classification disciplinaire du BSO
pub_year = [] #Année de publication
pub_date = [] #date de publication
pub_hal_id = [] #hal id de la publication
is_oa = [] #statut d'ouverture en 2024
list_ids = [] #id de la publication dans le fichier du BSO
list_rors = []

for n, x in enumerate(list_id_pub):
    
    dict_pub = datas[n]
    if 'authors' in dict_pub:
        #print(n, x)
        list_author = []
        list_author_id_s = []
        list_author_id_i = []
        list_author_orcid = []
        list_structures_id = []
        list_country = []
        list_address = []
        list_keyword = []
        list_ids.append(x)
        
        for a in dict_pub['authors']:
            #print(a)
            
            if  'full_name' in a:
                list_author.append(a['full_name'])
            else:
                list_author.append('no full_name')
            if 'id_hal_s' in a:
                list_author_id_s.append(a['id_hal_s'])
            else:
                list_author_id_s.append('no_id_hal_s')
            if 'id_hal_i'  in a:
                list_author_id_i.append(a['id_hal_i'])
            else:
                list_author_id_i.append('no_id_hal_i')
            if 'orcid' in a:
                list_author_orcid.append(a['orcid'])
            else:
                list_author_orcid.append('no orcid')
            if "affiliations" in a and len(a["affiliations"]) > 0 :
                dict_affil = a["affiliations"][0]
                if "country" in dict_affil:
                    list_country.append(dict_affil["country"])
                else:
                    list_country.append("no country")
                if "name" in dict_affil:
                    list_address.append(dict_affil["name"])
                else:
                    list_address.append("no address")
            else:
                list_country.append("no country")
                list_address.append("no address")
    
        authors_halid_s.append("|".join(list_author_id_s))
        authors_halid_i.append("|".join(list_author_id_i))
        authors_fullname.append("|".join(list_author))
        authors_orcid.append("|".join(list_author_orcid))
        structures_country.append("|".join(list_country))
        structures_address.append("|".join(list_address))

        if 'hal' in x:
            pub_hal_id.append(x[3:])
        else:
            pub_hal_id.append(np.nan)
        if 'hal_classification' in dict_pub:
            hal_classification = [h['code'] for h in dict_pub['hal_classification']]
            hal_class_code.append('|'.join(hal_classification))
        else:
            hal_class_code.append('no hal_classification')
        bso_class.append(dict_pub['bso_classification'])
        if 'keywords' in dict_pub:
            for kw in dict_pub["keywords"]:
                list_keyword.append(kw["keyword"])
        else:
            list_keyword.append('no keywords')
        affiliations_i = [inst for inst in dict_pub['bso_local_affiliations']  if re.search(r'[a-z]', inst) is None ]
        structures_id.append('|'.join(affiliations_i))
        #pub_date.append(dict_pub['published_date'])
        pub_year.append(dict_pub['year'])
        rors = dict_pub['rors']
        list_rors.append("|".join(rors))

        for y in dict_pub['oa_details']:
            if y == "2024Q4":
                dict_oa = dict_pub['oa_details'][y]
                #published_date.append(dict_pub['external_ids']['published_date'])
                is_oa.append(dict_oa["is_oa"])
    else:
        pass

# %%
data_columns = {
    "id": list_ids,
    'hal_id': pub_hal_id,
    "pub_year" : pub_year,
    'authors' : authors_fullname,
    'authhalid_s': authors_halid_s,
    'authhalid_i':authors_halid_i,
    'orcid': authors_orcid,
    'struchal_id': structures_id,
    'struc_country': structures_country,
    'struc_address': structures_address,
    'rors': list_rors,
    'hal_classif' : hal_class_code,
    'bso_classif' : bso_class,
    'is_oa': is_oa
}

df0 = pd.DataFrame(data= data_columns)
df0
# Out:
#                               id        hal_id  pub_year  \
# 0                halhal-03933378  hal-03933378      2019
# 1                halhal-03895949  hal-03895949      2017
# 2                halhal-01789653  hal-01789653      2017
# 3                halhal-03807832  hal-03807832      2014
# 4      doi10.3917/cliop.028.0029           NaN      2022
# ...                          ...           ...       ...
# 48081            halhal-04095338  hal-04095338      2020
# 48082            halhal-03299923  hal-03299923      2020
# 48083            halhal-04366816  hal-04366816      2023
# 48084            halhal-02120667  hal-02120667      2018
# 48085            halhal-01964707  hal-01964707      2020
#
#                                                  authors  \
# 0      Jérôme Livet|François Capron|Philippe Blanchar...
# 1                           Katerina Chryssanthaki-Nagle
# 2                                          Makis Solomos
# 3                                        Isabelle Launay
# 4      Léandro de Lajonquière|Floriana Baldassi D’Arrigo
# ...                                                  ...
# 48081                                     Céline Clément
# 48082                                    Martine Créac'H
# 48083  Brigitte Bardin|Anne Burguet|Sophie Henry|Nico...
# 48084  Valentina M. Azzarà|A.P. de Rorre|Jean-Francoi...
# 48085                                    Coralie Vincent
#
#                                              authhalid_s  \
# 0      jerome-livet|francois-capron|philippe-blanchar...
# 1                                            no_id_hal_s
# 2                                            no_id_hal_s
# 3                                            no_id_hal_s
# 4                                no_id_hal_s|no_id_hal_s
# ...                                                  ...
# 48081                            celine-clement-nanterre
# 48082                                     martine-creach
# 48083  brigitte-bardin|annette-burguet|sophie-henry|n...
# 48084  no_id_hal_s|no_id_hal_s|jean-francois-berger|g...
# 48085                                           cvincent
#
#                                              authhalid_i  \
# 0      176081|15426|18849|245|6836|2483|no_id_hal_i|1...
# 1                                            no_id_hal_i
# 2                                            no_id_hal_i
# 3                                            no_id_hal_i
# 4                                no_id_hal_i|no_id_hal_i
# ...                                                  ...
# 48081                                            1253116
# 48082                                             746578
# 48083                     1316897|753990|1327258|1268072
# 48084               no_id_hal_i|no_id_hal_i|742611|13749
# 48085                                               4552
#
#                                                    orcid  \
# 0      0000-0002-1785-776X|no orcid|0000-0003-0829-77...
# 1                                               no orcid
# 2                                               no orcid
# 3                                               no orcid
# 4                                      no orcid|no orcid
# ...                                                  ...
# 48081                                           no orcid
# 48082                                           no orcid
# 48083  no orcid|0009-0005-8979-2706|no orcid|0000-000...
# 48084  no orcid|no orcid|0000-0002-4360-7262|0000-000...
# 48085                                           no orcid
#
#                                              struchal_id  \
# 0      7550|199318270|205557|301475|1059646|11141|178...
# 1      7550|199318270|11141|300125|1003|441569|105964...
# 2                                 199318270|11141|188359
# 3                                 199318270|11141|188359
# 4                199318270|199411117|420786|106111|11141
# ...                                                  ...
# 48081        439352|441569|199318270|116205|443665|11141
# 48082                            199318270|1007102|11141
# 48083  199318270|193113842|217752|1052984|11141|42812...
# 48084  7550|199318270|301232|11141|300311|196901920|1...
# 48085               441569|199318270|204862|475360|11141
#
#                                            struc_country  \
# 0      France|France|France|France|France|France|Fran...
# 1                                             no country
# 2                                             no country
# 3                                             no country
# 4                                  no country|no country
# ...                                                  ...
# 48081                                         no country
# 48082                                         no country
# 48083                        France|France|France|France
# 48084                    France|no country|France|France
# 48085                                         no country
#
#                                            struc_address  \
# 0      Institut national de recherches archéologiques...
# 1      Archéologies et Sciences de l'Antiquité, UMR70...
# 2      Esthétique, musicologie, danse et création mus...
# 3      Esthétique, musicologie, danse et création mus...
# 4                                  no address|no address
# ...                                                  ...
# 48081  Genre, Travail, Mobilités, Cresppa-GTM, CRESPP...
# 48082  Fabrique du littéraire, EA7322, Fablitt, UP8, ...
# 48083  Laboratoire Parisien de Psychologie Sociale, E...
# 48084  Archéologies et Sciences de l'Antiquité, UMR70...
# 48085  Structures Formelles du Langage, UMR7023, UMR7...
#
#                                                     rors  \
# 0      https://ror.org/04wez5e68|https://ror.org/02ww...
# 1                              https://ror.org/04wez5e68
# 2                              https://ror.org/04wez5e68
# 3                              https://ror.org/04wez5e68
# 4      https://ror.org/04wez5e68|https://ror.org/05gg...
# ...                                                  ...
# 48081                          https://ror.org/04wez5e68
# 48082                          https://ror.org/04wez5e68
# 48083  https://ror.org/04wez5e68|https://ror.org/02v6...
# 48084  https://ror.org/04wez5e68|https://ror.org/050j...
# 48085                          https://ror.org/04wez5e68
#
#                                              hal_classif  \
# 0                                            shs.archeo_
# 1      shs.archeo_|shs.art_|shs.class_|shs.hist_|shs....
# 2                                             shs.musiq_
# 3                                        shs_|shs.musiq_
# 4                                      shs.edu_|shs.psy_
# ...                                                  ...
# 48081                               shs.demo_|shs.socio_
# 48082                                     shs_|shs.litt_
# 48083                                         scco.psyc_
# 48084                    shs.archeo_|sde.es_|sdu.stu.gp_
# 48085    spi.signal_|info.info-ts_|shs.musiq_|scco.ling_
#
#                                         bso_classif  is_oa
# 0                                        Humanities  False
# 1                                        Humanities  False
# 2                                        Humanities   True
# 3                                        Humanities  False
# 4                                   Social sciences  False
# ...                                             ...    ...
# 48081                               Social sciences  False
# 48082                                    Humanities  False
# 48083                                    Humanities   True
# 48084  Earth, Ecology, \nEnergy and applied biology  False
# 48085                                    Humanities   True
#
# [48086 rows x 14 columns]

# %%
with fs.open(f"{BUCKET_OUT}/Data_bso/outputs/publis/2026-02-18_list_of_publi_from_bso.csv", "w") as file_out:
    df0.to_csv(file_out, sep=",", index= False)

# %%
file_path = BUCKET_OUT + "/" + "Data_bso/fichier_from_mesr/bso-publications-latest_199318270_enriched.csv"
with fs.open(file_path) as csvin:
    df1 = pd.read_csv(csvin, sep =";")

# %% [markdown]
# ## Retrouver les informations géographiques à partir du ROR

# %%
df01 = df0[["id","rors"]]
df01["rors"] = df01.rors.str.split("|")
df_ror = df01.explode("rors")
# Out:
# /tmp/ipykernel_2541/4143035616.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df01["rors"] = df01.rors.str.split("|")

# %%
import requests
from requests.exceptions import HTTPError
import urllib.parse

# %%
ROR_API_ENDPOINT = "https://api.dev.ror.org/organizations"


params = {"query":"1m84wm78"} # le nombre de ligne. Par défaut, l'api affiche les 30 première ligne et le maximum fixé est de 10000.

# %%
query_response = requests.get(ROR_API_ENDPOINT + '/' + "01m84wm78").json()

# %%
query_response
# Out:
# {'admin': {'created': {'date': '2018-11-14', 'schema_version': '1.0'},
#   'last_modified': {'date': '2026-01-29', 'schema_version': '2.1'}},
#  'domains': [],
#  'established': 1969,
#  'external_ids': [{'all': ['grid.11619.3e'],
#    'preferred': 'grid.11619.3e',
#    'type': 'grid'},
#   {'all': ['0000 0001 2152 2279'], 'preferred': None, 'type': 'isni'},
#   {'all': ['Q459026'], 'preferred': None, 'type': 'wikidata'}],
#  'id': 'https://ror.org/01m84wm78',
#  'links': [{'type': 'website', 'value': 'http://www.univ-rennes2.fr/'},
#   {'type': 'wikipedia',
#    'value': 'http://en.wikipedia.org/wiki/University_of_Rennes_2_%E2%80%93_Upper_Brittany'}],
#  'locations': [{'geonames_details': {'continent_code': 'EU',
#     'continent_name': 'Europe',
#     'country_code': 'FR',
#     'country_name': 'France',
#     'country_subdivision_code': 'BRE',
#     'country_subdivision_name': 'Brittany',
#     'lat': 48.11198,
#     'lng': -1.67429,
#     'name': 'Rennes'},
#    'geonames_id': 2983990}],
#  'names': [{'lang': 'en',
#    'types': ['label'],
#    'value': 'University of Rennes 2'},
#   {'lang': 'fr',
#    'types': ['label', 'ror_display'],
#    'value': 'Université Rennes 2'}],
#  'relationships': [{'label': 'Laboratoire de Psychologie : Cognition, Comportement, Communication',
#    'type': 'child',
#    'id': 'https://ror.org/03dgmxj03'},
#   {'label': 'Institut de recherche mathématique de Rennes',
#    'type': 'child',
#    'id': 'https://ror.org/05y76vp22'},
#   {'label': 'Laboratoire Mouvement Sport Santé',
#    'type': 'child',
#    'id': 'https://ror.org/05b3p7p58'},
#   {'label': 'Anglophonie: communautés, écritures',
#    'type': 'child',
#    'id': 'https://ror.org/0595x5h51'},
#   {'label': 'Arts: pratiques et poétiques',
#    'type': 'child',
#    'id': 'https://ror.org/01k9kg969'},
#   {'label': 'Arènes: politique, santé publique, environnement, médias',
#    'type': 'child',
#    'id': 'https://ror.org/00m4rxj18'},
#   {'label': 'Centre d’études des langues et littératures anciennes et modernes',
#    'type': 'child',
#    'id': 'https://ror.org/045q3tp69'},
#   {'label': 'Centre d’Etudes des Langues, Territoires et Identités Culturelles – Bretagne et Langues Minoritaires',
#    'type': 'child',
#    'id': 'https://ror.org/05r4re112'},
#   {'label': 'Centre de Recherche en Archéologie, Archéosciences, Histoire',
#    'type': 'child',
#    'id': 'https://ror.org/02wgtm643'},
#   {'label': 'Centre de recherche sur l’éducation, les apprentissages et la didactique',
#    'type': 'child',
#    'id': 'https://ror.org/00psw8792'},
#   {'label': 'Équipe de Recherche Interlangue : Mémoires, Identités, Territoires',
#    'type': 'child',
#    'id': 'https://ror.org/0339jw085'},
#   {'label': 'Espaces et Sociétés',
#    'type': 'child',
#    'id': 'https://ror.org/03237mt20'},
#   {'label': 'Histoire et critique des arts',
#    'type': 'child',
#    'id': 'https://ror.org/018n13n96'},
#   {'label': 'Littoral, Environnement, Télédétection, Géomatique',
#    'type': 'child',
#    'id': 'https://ror.org/05sat2s07'},
#   {'label': 'Linguistique Ingénierie et Didactique des Langues',
#    'type': 'child',
#    'id': 'https://ror.org/02gn4cf81'},
#   {'label': 'Laboratoire Interdisciplinaire de Recherche en Innovations Sociétales',
#    'type': 'child',
#    'id': 'https://ror.org/01dyfj824'},
#   {'label': 'Pôle de Recherche Francophonies, Interculturel, Communication, Sociolinguistique',
#    'type': 'child',
#    'id': 'https://ror.org/01pxcyx49'},
#   {'label': "Pratiques et Théories de l'art contemporain",
#    'type': 'child',
#    'id': 'https://ror.org/00drkdp66'},
#   {'label': 'Recherches en Psychopathologie et Psychanalyse',
#    'type': 'child',
#    'id': 'https://ror.org/04fke6556'},
#   {'label': 'Tempora', 'type': 'child', 'id': 'https://ror.org/05rmjk207'},
#   {'label': 'Valeurs, Innovations, Politiques, Socialisations et Sports',
#    'type': 'child',
#    'id': 'https://ror.org/026m1rk14'},
#   {'label': "Observatoire des Sciences de l'Environnement de Rennes",
#    'type': 'child',
#    'id': 'https://ror.org/05pwkex33'},
#   {'label': 'Maison des sciences humaines et sociales en Bretagne',
#    'type': 'child',
#    'id': 'https://ror.org/01jwwzm25'}],
#  'status': 'active',
#  'types': ['education']}

# %%
for n, x in enumerate(query_response["names"]):
    if 'ror_display' in x["types"]:
        print(x)
# Out:
# {'lang': 'fr', 'types': ['label', 'ror_display'], 'value': 'Université Rennes 2'}

# %%
dict_ror = {}
list_row = []
for ror in df_ror.rors.unique():
    dict_row ={}
    rorid = ror.split("/")[-1]
    #print(rorid)
    dict_ror[ror] = rorid
    dict_row["ror"] = ror
    data = requests.get(ROR_API_ENDPOINT + '/' + rorid).json()

    for n, x in enumerate(data["names"]):
        if 'ror_display' in x["types"]:
            dict_row["nom"] = x["value"]
    locations_data = data["locations"][0]["geonames_details"]
    for i in locations_data:
        dict_row[i] = locations_data[i]
        if i == "name":
            dict_row["city"] = locations_data[i]
    dict_row["geonames_id"] = data["locations"][0]["geonames_id"]
    list_row.append(dict_row)

# %%
df_inst = pd.DataFrame.from_dict(list_row)

# %%
df_inst.country_name.value_counts()
# Out:
# country_name
# France    155
# Name: count, dtype: int64

# %% [markdown]
# ## Retrouver le ror à partir du nom des universités
#
# Dans les données enrichies, le ror est présent uniquement pour les établissement français. On va essayer de récupérer le ror à partir de l'adresse des structures (lorsqu'elle est indiquée)

# %%
df02 = df0[["id","struc_address"]]
df02["address"] = df02.struc_address.str.split("|")
df_ad = df02.explode("address")
df_ad2 = df_ad.loc[~(df_ad.address.str.contains('no address|France'))]
df_ad2.address.iloc[1]
# Out:
# /tmp/ipykernel_2541/472175067.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df02["address"] = df02.struc_address.str.split("|")
# 'École doctorale Pratiques et théories du sens'

# %%
key ='École doctorale Pratiques et théories du sens'
status_response = requests.get(ROR_API_ENDPOINT + '?' + f'query="{key}"').json()
status_response
# Out:
# {'number_of_results': 0,
#  'time_taken': 51,
#  'items': [],
#  'meta': {'types': [], 'countries': [], 'continents': [], 'statuses': []}}

# %%
dict_ror2 = {}
for m, a in enumerate(df_ad2.address.unique()):
    row_id = m
    a_split = a.split(",")
    nom_univ = re.sub(r"\[.*\]", "", a_split[0]).strip().replace("&egrave;", "è").lower()
    print(nom_univ)
    #key ='École doctorale Pratiques et théories du sens'
    response = requests.get(ROR_API_ENDPOINT + '?' + f'query="{nom_univ}"').json()
    try:
        if response["number_of_results"] > 1 :
            for n, x in enumerate(response["meta"]["types"]):
                if 'education' in x["id"]:
                    data = response["items"][n]
                    #print(data["id"])
        elif response["number_of_results"] == 1 :
            data = response["items"][0]
            #print(data["id"])
        dict_ror2[row_id] = data["id"]
    except:
        print(nom_univ)
# Out:
# nos últimos trinta anos nos últimos trinta anos
# école doctorale pratiques et théories du sens
# archeodunum
# université de paris viii
# université laval
# revue des arts et médiations humaines revue des arts et médiations humaines
# ecole nationale des sciences appliquées
# université de la manouba
# université paris 8 : laboratoire d’études et de recherches sur les logiques contemporaines de la philosophie (llcp ea 4008).
# école doctorale galilée
# the university of tennessee
# école doctorale sciences sociales
# eberhard karls universität tübingen =  university of tübingen
# dans la réforme du travail au mexique dans la réforme du travail au mexique
# direction régionale de la pêche de koulikoro
# institut français de pondichéry
# universidad nacional del centro de la provincia de buenos aires
# département d'etude sur l'adaptation scolaire et sociale
# iranian center for archaeological research
# university professor (exceptional class) at the university of paris university of paris
# university of kansas
# école doctorale esthétique
# exploration and excavation branch
# laboratoire de recherche de mécanique
# national school of engineers of sfax
# graduate school of material science
# fundação joão pinheiro
# école doctorale abbé grégoire
# rheinisch-westfälische technische hochschule aachen university
# università degli studi di roma "la sapienza" = sapienza university
# institut national d'aménagement et d'urbanisme
# unité de modélisation
# national school of engineers of sfax
# école nationale d'ingénieurs de sfax
# national school of engineers of sfax
# school of mathematics and statistics
# aristotle university of thessaloniki
# faculte´ des sciences
# institut national de la recherche agronomique
# université paris nanterre
# nutritional epidemiology research team
# equipe de recherche en epidémiologie nutritionnelle
# école doctorale espaces
# universidade de lisboa = university of lisbon = université de lisbonne
# university of strathclyde
# école de gestion telfer / université d'ottawa
# université m'hamed bougara boumerdes
# « blacking up : une histoire du rock au prisme du blacking up : une histoire du rock au prisme
# universidad de parís 8
# « le forum mondial de l'eau le forum mondial de l'eau
# university of paris
# cahiers philosophiques de strasbourg les cahiers philosophiques de strasbourg cahiers philosophiques de strasbourg les cahiers philosophiques de strasbourg
# heilongjiang bayi agricultural university
# matej bel university
# dipartimento di elettronica informatica e sistemistica
# the horsemen of athens
# université de franche-comté
# inspe de l’académie de versailles
# department of earth and planetary sciences
# school of earth sciences
# natural history museum of denmark
# maître de conférences en histoire contemporaine
# .info pour éditions du croquant. © .info pour éditions du croquant. ©
# pembroke college
# university of texas at austin
# paris 8 university .triangle {fill:#53baa1;} .letter-r {fill:#202826;}
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File /opt/python/lib/python3.13/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/python/lib/python3.13/json/__init__.py:352, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     349 if (cls is None and object_hook is None and
#     350         parse_int is None and parse_float is None and
#     351         parse_constant is None and object_pairs_hook is None and not kw):
# --> 352     return _default_decoder.decode(s)
#     353 if cls is None:
#
# File /opt/python/lib/python3.13/json/decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     341 """Return the Python representation of ``s`` (a ``str`` instance
#     342 containing a JSON document).
#     343
#     344 """
# --> 345 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346 end = _w(s, end).end()
#
# File /opt/python/lib/python3.13/json/decoder.py:363, in JSONDecoder.raw_decode(self, s, idx)
#     362 except StopIteration as err:
# --> 363     raise JSONDecodeError("Expecting value", s, err.value) from None
#     364 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[55], line 8
#       6 print(nom_univ)
#       7 #key ='École doctorale Pratiques et théories du sens'
# ----> 8 response = requests.get(ROR_API_ENDPOINT + '?' + f'query="{nom_univ}"').json()
#       9 try:
#      10     if response["number_of_results"] > 1 :
#
# File /opt/python/lib/python3.13/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
df0
# Out:
#                               id        hal_id  pub_year  \
# 0                halhal-03933378  hal-03933378      2019
# 1                halhal-03895949  hal-03895949      2017
# 2                halhal-01789653  hal-01789653      2017
# 3                halhal-03807832  hal-03807832      2014
# 4      doi10.3917/cliop.028.0029           NaN      2022
# ...                          ...           ...       ...
# 48081            halhal-04095338  hal-04095338      2020
# 48082            halhal-03299923  hal-03299923      2020
# 48083            halhal-04366816  hal-04366816      2023
# 48084            halhal-02120667  hal-02120667      2018
# 48085            halhal-01964707  hal-01964707      2020
#
#                                                  authors  \
# 0      Jérôme Livet|François Capron|Philippe Blanchar...
# 1                           Katerina Chryssanthaki-Nagle
# 2                                          Makis Solomos
# 3                                        Isabelle Launay
# 4      Léandro de Lajonquière|Floriana Baldassi D’Arrigo
# ...                                                  ...
# 48081                                     Céline Clément
# 48082                                    Martine Créac'H
# 48083  Brigitte Bardin|Anne Burguet|Sophie Henry|Nico...
# 48084  Valentina M. Azzarà|A.P. de Rorre|Jean-Francoi...
# 48085                                    Coralie Vincent
#
#                                              authhalid_s  \
# 0      jerome-livet|francois-capron|philippe-blanchar...
# 1                                            no_id_hal_s
# 2                                            no_id_hal_s
# 3                                            no_id_hal_s
# 4                                no_id_hal_s|no_id_hal_s
# ...                                                  ...
# 48081                            celine-clement-nanterre
# 48082                                     martine-creach
# 48083  brigitte-bardin|annette-burguet|sophie-henry|n...
# 48084  no_id_hal_s|no_id_hal_s|jean-francois-berger|g...
# 48085                                           cvincent
#
#                                              authhalid_i  \
# 0      176081|15426|18849|245|6836|2483|no_id_hal_i|1...
# 1                                            no_id_hal_i
# 2                                            no_id_hal_i
# 3                                            no_id_hal_i
# 4                                no_id_hal_i|no_id_hal_i
# ...                                                  ...
# 48081                                            1253116
# 48082                                             746578
# 48083                     1316897|753990|1327258|1268072
# 48084               no_id_hal_i|no_id_hal_i|742611|13749
# 48085                                               4552
#
#                                                    orcid  \
# 0      0000-0002-1785-776X|no orcid|0000-0003-0829-77...
# 1                                               no orcid
# 2                                               no orcid
# 3                                               no orcid
# 4                                      no orcid|no orcid
# ...                                                  ...
# 48081                                           no orcid
# 48082                                           no orcid
# 48083  no orcid|0009-0005-8979-2706|no orcid|0000-000...
# 48084  no orcid|no orcid|0000-0002-4360-7262|0000-000...
# 48085                                           no orcid
#
#                                              struchal_id  \
# 0      7550|199318270|205557|301475|1059646|11141|178...
# 1      7550|199318270|11141|300125|1003|441569|105964...
# 2                                 199318270|11141|188359
# 3                                 199318270|11141|188359
# 4                199318270|199411117|420786|106111|11141
# ...                                                  ...
# 48081        439352|441569|199318270|116205|443665|11141
# 48082                            199318270|1007102|11141
# 48083  199318270|193113842|217752|1052984|11141|42812...
# 48084  7550|199318270|301232|11141|300311|196901920|1...
# 48085               441569|199318270|204862|475360|11141
#
#                                            struc_country  \
# 0      France|France|France|France|France|France|Fran...
# 1                                             no country
# 2                                             no country
# 3                                             no country
# 4                                  no country|no country
# ...                                                  ...
# 48081                                         no country
# 48082                                         no country
# 48083                        France|France|France|France
# 48084                    France|no country|France|France
# 48085                                         no country
#
#                                            struc_address  \
# 0      Institut national de recherches archéologiques...
# 1      Archéologies et Sciences de l'Antiquité, UMR70...
# 2      Esthétique, musicologie, danse et création mus...
# 3      Esthétique, musicologie, danse et création mus...
# 4                                  no address|no address
# ...                                                  ...
# 48081  Genre, Travail, Mobilités, Cresppa-GTM, CRESPP...
# 48082  Fabrique du littéraire, EA7322, Fablitt, UP8, ...
# 48083  Laboratoire Parisien de Psychologie Sociale, E...
# 48084  Archéologies et Sciences de l'Antiquité, UMR70...
# 48085  Structures Formelles du Langage, UMR7023, UMR7...
#
#                                                     rors  \
# 0      https://ror.org/04wez5e68|https://ror.org/02ww...
# 1                              https://ror.org/04wez5e68
# 2                              https://ror.org/04wez5e68
# 3                              https://ror.org/04wez5e68
# 4      https://ror.org/04wez5e68|https://ror.org/05gg...
# ...                                                  ...
# 48081                          https://ror.org/04wez5e68
# 48082                          https://ror.org/04wez5e68
# 48083  https://ror.org/04wez5e68|https://ror.org/02v6...
# 48084  https://ror.org/04wez5e68|https://ror.org/050j...
# 48085                          https://ror.org/04wez5e68
#
#                                              hal_classif  \
# 0                                            shs.archeo_
# 1      shs.archeo_|shs.art_|shs.class_|shs.hist_|shs....
# 2                                             shs.musiq_
# 3                                        shs_|shs.musiq_
# 4                                      shs.edu_|shs.psy_
# ...                                                  ...
# 48081                               shs.demo_|shs.socio_
# 48082                                     shs_|shs.litt_
# 48083                                         scco.psyc_
# 48084                    shs.archeo_|sde.es_|sdu.stu.gp_
# 48085    spi.signal_|info.info-ts_|shs.musiq_|scco.ling_
#
#                                         bso_classif  is_oa
# 0                                        Humanities  False
# 1                                        Humanities  False
# 2                                        Humanities   True
# 3                                        Humanities  False
# 4                                   Social sciences  False
# ...                                             ...    ...
# 48081                               Social sciences  False
# 48082                                    Humanities  False
# 48083                                    Humanities   True
# 48084  Earth, Ecology, \nEnergy and applied biology  False
# 48085                                    Humanities   True
#
# [48086 rows x 14 columns]
