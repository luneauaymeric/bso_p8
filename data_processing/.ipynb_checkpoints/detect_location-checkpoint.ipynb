# %% [markdown]
# # Récupérer les données géographiques (pays, villes)

# %%
#chargement des modules
import pandas as pd
import datetime
import os
import json
from io import StringIO
import numpy as np
import plotly.express as px
import re

# %%
import s3fs #pour connecter au bucket

# %%
# Create filesystem object
S3_ENDPOINT_URL = "https://" + os.environ["AWS_S3_ENDPOINT"]
fs = s3fs.S3FileSystem(client_kwargs={'endpoint_url': S3_ENDPOINT_URL})

BUCKET_OUT = "aluneau"

# %%
with fs.open(f"{BUCKET_OUT}/Data_bso/outputs/enriched_data/geolocation/2026-03-11_publi_from_bso_with_address.csv", "r") as file_in:
    df0 = pd.read_csv(file_in, sep=",")

# %%
file_path = BUCKET_OUT + "/" + "Data_bso/fichier_from_mesr/bso-publications-latest_199318270_enriched.csv"
with fs.open(file_path) as csvin:
    df1 = pd.read_csv(csvin, sep =";")

df1.columns
# Out:
# Index(['observation_date', 'id', 'doi', 'pmid', 'hal_id', 'year', 'title',
#        'journal_issns', 'journal_issn_l', 'journal_name', 'publisher',
#        'publisher_dissemination', 'bso_classification', 'lang', 'genre',
#        'amount_apc_EUR', 'apc_source', 'domains', 'detected_countries',
#        'bso_local_affiliations', 'rors', 'funding_anr', 'funding_europe',
#        'bsso_classification', 'is_oa', 'is_oa_hal', 'oa_host_type',
#        'journal_is_in_doaj', 'journal_is_oa', 'unpaywall_oa_status',
#        'oa_colors', 'licence_publisher', 'licence_repositories',
#        'repositories', 'software_mentions', 'data_mentions', 'software_used',
#        'software_created', 'software_shared', 'data_used', 'data_created',
#        'data_shared', 'missing_doi_in_hal', 'has_doi_in_hal', 'doi_in_hal',
#        'bso_country'],
#       dtype='object')

# %% [markdown]
# ## Retrouver les informations géographiques à partir du ROR

# %% [markdown]
# L'objectif est d'utiliser l'api de ROR pour récupérer des données géographiques à partir de l'identifiation ROR des institutions. Le problème est que toutes les institutions recencées dans le BSO n'ont pas de ROR. L'analyse des données montre qu'on dispose du ROR uniquement pour les établissement français.
#
# On utilise la librairie requests pour interroger l'API

# %%
df01 = df0[["id","rors"]]
df01["rors"] = df01.rors.str.split("|")
df_ror = df01.explode("rors")
# Out:
# /tmp/ipykernel_11041/4143035616.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df01["rors"] = df01.rors.str.split("|")

# %%
import requests
from requests.exceptions import HTTPError
import urllib.parse
import tqdm

# %%
ROR_API_ENDPOINT = "https://api.dev.ror.org/organizations"


params = {"query":"1m84wm78"} # le nombre de ligne. Par défaut, l'api affiche les 30 première ligne et le maximum fixé est de 10000.

# %%
query_response = requests.get(ROR_API_ENDPOINT + '/' + "01m84wm78").json()

# %% [markdown]
# On affiche la structure des données

# %%
query_response
# Out:
# {'admin': {'created': {'date': '2018-11-14', 'schema_version': '1.0'},
#   'last_modified': {'date': '2026-01-29', 'schema_version': '2.1'}},
#  'domains': [],
#  'established': 1969,
#  'external_ids': [{'all': ['grid.11619.3e'],
#    'preferred': 'grid.11619.3e',
#    'type': 'grid'},
#   {'all': ['0000 0001 2152 2279'], 'preferred': None, 'type': 'isni'},
#   {'all': ['Q459026'], 'preferred': None, 'type': 'wikidata'}],
#  'id': 'https://ror.org/01m84wm78',
#  'links': [{'type': 'website', 'value': 'http://www.univ-rennes2.fr/'},
#   {'type': 'wikipedia',
#    'value': 'http://en.wikipedia.org/wiki/University_of_Rennes_2_%E2%80%93_Upper_Brittany'}],
#  'locations': [{'geonames_details': {'continent_code': 'EU',
#     'continent_name': 'Europe',
#     'country_code': 'FR',
#     'country_name': 'France',
#     'country_subdivision_code': 'BRE',
#     'country_subdivision_name': 'Brittany',
#     'lat': 48.11198,
#     'lng': -1.67429,
#     'name': 'Rennes'},
#    'geonames_id': 2983990}],
#  'names': [{'lang': 'en',
#    'types': ['label'],
#    'value': 'University of Rennes 2'},
#   {'lang': 'fr',
#    'types': ['label', 'ror_display'],
#    'value': 'Université Rennes 2'}],
#  'relationships': [{'label': 'Laboratoire de Psychologie : Cognition, Comportement, Communication',
#    'type': 'child',
#    'id': 'https://ror.org/03dgmxj03'},
#   {'label': 'Institut de recherche mathématique de Rennes',
#    'type': 'child',
#    'id': 'https://ror.org/05y76vp22'},
#   {'label': 'Laboratoire Mouvement Sport Santé',
#    'type': 'child',
#    'id': 'https://ror.org/05b3p7p58'},
#   {'label': 'Anglophonie: communautés, écritures',
#    'type': 'child',
#    'id': 'https://ror.org/0595x5h51'},
#   {'label': 'Arts: pratiques et poétiques',
#    'type': 'child',
#    'id': 'https://ror.org/01k9kg969'},
#   {'label': 'Arènes: politique, santé publique, environnement, médias',
#    'type': 'child',
#    'id': 'https://ror.org/00m4rxj18'},
#   {'label': 'Centre d’études des langues et littératures anciennes et modernes',
#    'type': 'child',
#    'id': 'https://ror.org/045q3tp69'},
#   {'label': 'Centre d’Etudes des Langues, Territoires et Identités Culturelles – Bretagne et Langues Minoritaires',
#    'type': 'child',
#    'id': 'https://ror.org/05r4re112'},
#   {'label': 'Centre de Recherche en Archéologie, Archéosciences, Histoire',
#    'type': 'child',
#    'id': 'https://ror.org/02wgtm643'},
#   {'label': 'Centre de recherche sur l’éducation, les apprentissages et la didactique',
#    'type': 'child',
#    'id': 'https://ror.org/00psw8792'},
#   {'label': 'Équipe de Recherche Interlangue : Mémoires, Identités, Territoires',
#    'type': 'child',
#    'id': 'https://ror.org/0339jw085'},
#   {'label': 'Espaces et Sociétés',
#    'type': 'child',
#    'id': 'https://ror.org/03237mt20'},
#   {'label': 'Histoire et critique des arts',
#    'type': 'child',
#    'id': 'https://ror.org/018n13n96'},
#   {'label': 'Littoral, Environnement, Télédétection, Géomatique',
#    'type': 'child',
#    'id': 'https://ror.org/05sat2s07'},
#   {'label': 'Linguistique Ingénierie et Didactique des Langues',
#    'type': 'child',
#    'id': 'https://ror.org/02gn4cf81'},
#   {'label': 'Laboratoire Interdisciplinaire de Recherche en Innovations Sociétales',
#    'type': 'child',
#    'id': 'https://ror.org/01dyfj824'},
#   {'label': 'Pôle de Recherche Francophonies, Interculturel, Communication, Sociolinguistique',
#    'type': 'child',
#    'id': 'https://ror.org/01pxcyx49'},
#   {'label': "Pratiques et Théories de l'art contemporain",
#    'type': 'child',
#    'id': 'https://ror.org/00drkdp66'},
#   {'label': 'Recherches en Psychopathologie et Psychanalyse',
#    'type': 'child',
#    'id': 'https://ror.org/04fke6556'},
#   {'label': 'Tempora', 'type': 'child', 'id': 'https://ror.org/05rmjk207'},
#   {'label': 'Valeurs, Innovations, Politiques, Socialisations et Sports',
#    'type': 'child',
#    'id': 'https://ror.org/026m1rk14'},
#   {'label': "Observatoire des Sciences de l'Environnement de Rennes",
#    'type': 'child',
#    'id': 'https://ror.org/05pwkex33'},
#   {'label': 'Maison des sciences humaines et sociales en Bretagne',
#    'type': 'child',
#    'id': 'https://ror.org/01jwwzm25'}],
#  'status': 'active',
#  'types': ['education']}

# %%
for n, x in enumerate(query_response["names"]):
    if 'ror_display' in x["types"]:
        print(x)
# Out:
# {'lang': 'fr', 'types': ['label', 'ror_display'], 'value': 'Université Rennes 2'}

# %% [markdown]
# Nous voulons récupérer les informations contenues dans "locations" :
#
# ```
# locations': [{'geonames_details': {'continent_code': 'EU',
#     'continent_name': 'Europe',
#     'country_code': 'FR',
#     'country_name': 'France',
#     'country_subdivision_code': 'BRE',
#     'country_subdivision_name': 'Brittany',
#     'lat': 48.11198,
#     'lng': -1.67429,
#     'name': 'Rennes'},
#
# ```

# %%
dict_ror = {}
list_row = []
for ror in tqdm.tqdm(df_ror.rors.unique(), total = df_ror.rors.nunique()):
    dict_row ={}
    rorid = ror.split("/")[-1]
    #print(rorid)
    dict_ror[ror] = rorid
    dict_row["rors"] = ror
    data = requests.get(ROR_API_ENDPOINT + '/' + rorid).json()

    for n, x in enumerate(data["names"]):
        if 'ror_display' in x["types"]:
            dict_row["nom"] = x["value"]
    locations_data = data["locations"][0]["geonames_details"]
    for i in locations_data:
        dict_row[i] = locations_data[i]
        if i == "name":
            dict_row["city"] = locations_data[i]
    dict_row["geonames_id"] = data["locations"][0]["geonames_id"]
    list_row.append(dict_row)
# Out:
# 100%|██████████| 155/155 [00:20<00:00,  7.50it/s]

# %%
df_inst = pd.DataFrame.from_dict(list_row)

# %%
df_inst.country_name.value_counts()
df_inst
# Out:
#                           rors  \
# 0    https://ror.org/04wez5e68
# 1    https://ror.org/02wwzvj46
# 2    https://ror.org/057qpr032
# 3    https://ror.org/05ggc9x40
# 4    https://ror.org/01qhqcj41
# ..                         ...
# 150  https://ror.org/03pnp1a74
# 151  https://ror.org/042xmz674
# 152  https://ror.org/04fm0sh33
# 153  https://ror.org/022zdgq74
# 154  https://ror.org/052xwpe12
#
#                                                    nom continent_code  \
# 0                                   Université Paris 8             EU
# 1                                  Université de Tours             EU
# 2                               Université de Bordeaux             EU
# 3                         Université Paris-Est Créteil             EU
# 4                  Université de Technologie de Troyes             EU
# ..                                                 ...            ...
# 150                                            Lamsade             EU
# 151  Laboratoire de Physique et Chimie des Nano-Objets             EU
# 152         Laboratoire de Planétologie et Géosciences             EU
# 153               École Nationale de l’Aviation Civile             EU
# 154                       EM Normandie Business School             EU
#
#     continent_name country_code country_name country_subdivision_code  \
# 0           Europe           FR       France                      IDF
# 1           Europe           FR       France                      CVL
# 2           Europe           FR       France                      NAQ
# 3           Europe           FR       France                      IDF
# 4           Europe           FR       France                      GES
# ..             ...          ...          ...                      ...
# 150         Europe           FR       France                      IDF
# 151         Europe           FR       France                      OCC
# 152         Europe           FR       France                      PDL
# 153         Europe           FR       France                      OCC
# 154         Europe           FR       France                      NOR
#
#     country_subdivision_name       lat      lng      name      city  \
# 0              Île-de-France  48.85341  2.34880     Paris     Paris
# 1        Centre-Val de Loire  47.39484  0.70398     Tours     Tours
# 2         Nouvelle-Aquitaine  44.84124 -0.58046  Bordeaux  Bordeaux
# 3              Île-de-France  48.79266  2.46569   Créteil   Créteil
# 4                  Grand Est  48.30073  4.08524    Troyes    Troyes
# ..                       ...       ...      ...       ...       ...
# 150            Île-de-France  48.85341  2.34880     Paris     Paris
# 151                Occitanie  43.60426  1.44367  Toulouse  Toulouse
# 152         Pays de la Loire  47.21725 -1.55336    Nantes    Nantes
# 153                Occitanie  43.60426  1.44367  Toulouse  Toulouse
# 154                 Normandy  49.49346  0.10785  Le Havre  Le Havre
#
#      geonames_id
# 0        2988507
# 1        2972191
# 2        3031582
# 3        3022530
# 4        2971549
# ..           ...
# 150      2988507
# 151      2972315
# 152      2990969
# 153      2972315
# 154      3003796
#
# [155 rows x 13 columns]

# %%
with fs.open(f"{BUCKET_OUT}/Data_bso/outputs/enriched_data/geolocation/2026-03-11_geographical_info_french_affiliation.csv", "w") as file_out:
    df_inst.to_csv(file_out, sep=",", index= False)

# %%
with fs.open(f"{BUCKET_OUT}/Data_bso/outputs/enriched_data/geolocation/2026-03-11_publication_with_french_affiliation.csv", "w") as file_out:
    df_ror.merge(df_inst, on = ["rors"], how = "left").drop_duplicates().to_csv(file_out, sep=",", index= False)

# %% [markdown]
# ## Retrouver le ror à partir du nom des universités
#
# Dans les données enrichies, le ror est présent uniquement pour les établissement français. On va essayer de récupérer le ror à partir de l'adresse des structures (lorsqu'elle est indiquée).
# Pour cela, nous allons utilisés plus informations et plusieurs technique. L'objectif est de récupérer le nomn de l'établissement et la ville.
#
# Lorsqu'il y a une adresse dans les données du bso (variable nommée `address`), nous l'utilisons en priorité. S'il n'y en a pas ou que les informations contenues ne permettent de retrouver des indications géographiques, on utilise l'affiliation retrouvée via Crossref.
#
#
# **Pour certaines lignes, le texte présent dans les colonne "struc_address" et "address" correspondent en fait soit au titre soit au résumé de la plublication.**
#
#
# Concernant les techniques, on utilise d'abord les regex, puis des outils de reconnaissance d'entité nommée (Spacy)

# %%
file_path = BUCKET_OUT + "/" + "Data_bso/outputs/enriched_data/geolocation/2026-03-11_affil_crossref.csv"
with fs.open(file_path) as csvin:
    dfcr = pd.read_csv(csvin, sep =",")


dfcr1 = dfcr.loc[dfcr.affiliation!="no affil"]

df01 = df0.merge(dfcr1[["id","affiliation"]], on = ["id"], how = "left").merge(df1[["id","title"]], on = ["id"], how = "left")#.reset_index()

# %%
df02 = df01[["id","struc_address","affiliation","title"]]
df02["address"] = df02.struc_address.str.split("|")
df_ad = df02[['id','affiliation','title','address']].explode("address").drop_duplicates().dropna(subset="address").reset_index().drop(columns=["index"])

#On isole les adresses françaises
df_adfr = df_ad.loc[(df_ad.address.str.lower().str.contains("france|paris"))].reset_index().drop(columns=["index"])

df_adfr
# Out:
# /tmp/ipykernel_11041/4099095763.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df02["address"] = df02.struc_address.str.split("|")
#                     id affiliation  \
# 0      halhal-03933378         NaN
# 1      halhal-03933378         NaN
# 2      halhal-03933378         NaN
# 3      halhal-03933378         NaN
# 4      halhal-03933378         NaN
# ...                ...         ...
# 56312  halhal-04366816         NaN
# 56313  halhal-02120667         NaN
# 56314  halhal-02120667         NaN
# 56315  halhal-02120667         NaN
# 56316  halhal-01964707         NaN
#
#                                                    title  \
# 0      Typo-chronologie des tombes à inhumation en ré...
# 1      Typo-chronologie des tombes à inhumation en ré...
# 2      Typo-chronologie des tombes à inhumation en ré...
# 3      Typo-chronologie des tombes à inhumation en ré...
# 4      Typo-chronologie des tombes à inhumation en ré...
# ...                                                  ...
# 56312  The Language of Bias: Unveiling Implicit Attit...
# 56313  The archaeological project at Ra's al-Jinz RJ3...
# 56314  The archaeological project at Ra's al-Jinz RJ3...
# 56315  The archaeological project at Ra's al-Jinz RJ3...
# 56316  Annotating Multimodal data of Singing and Spea...
#
#                                                  address
# 0      Institut national de recherches archéologiques...
# 1      Cités, Territoires, Environnement et Sociétés,...
# 2      Service de l'archéologie du département d'Indr...
# 3      EVEHA (Etudes et valorisations archeologiques)...
# 4      Service Archéologique Municipal d'Orléans, 13 ...
# ...                                                  ...
# 56312  Laboratoire sur les Interactions Cognition, Ac...
# 56313  Archéologies et Sciences de l'Antiquité, UMR70...
# 56314  Environnement, Ville, Société, UMR5600, UMR560...
# 56315  LIttoral ENvironnement et Sociétés, UMR7266, L...
# 56316  Structures Formelles du Langage, UMR7023, UMR7...
#
# [56317 rows x 4 columns]

# %%
df_adfr["rank_id"] = df_adfr.index.astype(str)
df_adfr["name_umr"] = df_adfr.apply(lambda row:"|".join(set([x.replace(" ","") for x in re.findall(r"(?:umr|ums|ea).\d+\b", str(row.address).lower())])),1)

df_adfr.loc[df_adfr.name_umr.str.contains("ums")]
# Out:
#                         id affiliation  \
# 878    halmedihal-01925578         NaN
# 1123       halhal-02180687         NaN
# 1645       halhal-01315200         NaN
# 2023       halhal-03101060         NaN
# 2348       halhal-00869953         NaN
# ...                    ...         ...
# 54571      halhal-04657865         NaN
# 54611      halhal-03378997         NaN
# 54781   halhalshs-01374894         NaN
# 54919      halhal-04270523         NaN
# 55747      halhal-03714423         NaN
#
#                                                    title  \
# 878    Film réalisé dans le cadre de "14-18 Mission C...
# 1123                                La lecture numérique
# 1645   Cultural evolution and burial discontinuities ...
# 2023   Activités illégales dans/autour d’une aire pro...
# 2348   Visual attention in a complex task: discrimina...
# ...                                                  ...
# 54571  Synthèse du groupe de travail RnMSH sur les re...
# 54611  Restauration écologique de la rivière Sélune. ...
# 54781  Étude de cas : l’anticartogramme, un exemple p...
# 54919  Les fers médiévaux de Notre-Dame de Paris : ch...
# 55747  Hyères, Olbia de Provence / Parking du bord de...
#
#                                                  address rank_id  \
# 878    Archeovision CNRS, UMS3657 / UPS3551, UB, UBM,...     878
# 1123   Laboratoire des Usages en Technologies d'Infor...    1123
# 1645   Eco-Anthropologie et Ethnobiologie, UMS104, UM...    1645
# 2023   Eco-Anthropologie et Ethnobiologie, UMS104, UM...    2023
# 2348   Laboratoire des Usages en Technologies d'Infor...    2348
# ...                                                  ...     ...
# 54571  Structuration et Internationalisation des SHS,...   54571
# 54611  Réseau interdisciplinaire pour l’aménagement e...   54611
# 54781  Réseau interdisciplinaire pour l'aménagement e...   54781
# 54919  Laboratoire de mesure du carbone 14, DSM/LSCE,...   54919
# 55747  Centre Jean Berard, UMS1797, CJB, EFR, CNRS, E...   55747
#
#              name_umr
# 878           ums3657
# 1123          ums2809
# 1645   umr7206|ums104
# 2023   umr7206|ums104
# 2348          ums2809
# ...               ...
# 54571         ums3603
# 54611         ums2414
# 54781         ums2414
# 54919         ums2572
# 55747         ums1797
#
# [102 rows x 6 columns]

# %%
df_adfr["address"] = df_adfr.apply(lambda row: re.sub("Paris VIII", "Paris 8", str(row.address)),1)
df_adfr["address"] = df_adfr.apply(lambda row: re.sub("Paris XIII", "Paris 13", str(row.address)),1)
df_adfr["address"] = df_adfr.apply(lambda row: re.sub("Paris X", "Paris Nanterre", str(row.address)),1)

# %%
df_frwithoutumr = df_adfr.loc[df_adfr.name_umr==""]

# %%
# !python -m spacy download fr_core_news_md
# Out:
# Collecting fr-core-news-md==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_md-3.8.0/fr_core_news_md-3.8.0-py3-none-any.whl (45.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 MB 55.4 MB/s  0:00:00m0:00:0100:01
# ✔ Download and installation successful
# You can now load the package via spacy.load('fr_core_news_md')

# %%
import spacy

# %%
regex_match = {}

for index, row in df_adfr.iterrows():
    #print("######", row.address)
    address = re.sub(r"'|’", " ", str(row.address))
    split_address = set(re.sub(r"\s\-\s|;", ",",address.lower()).split(","))
    lower_address = ", ".join(split_address)
    regex = r"(?:univ\w*|collège|institut|école|school)[\s\w-]*\b"
    regex2=r'\b[\s\w-]+(?:univ\w*|collège|institut|école|school)\b'
    find_univ = re.findall(regex, lower_address)
    find_univ2 = [x.strip() for x in re.findall(regex2, lower_address) if x not in find_univ]

    list_univ = set(find_univ + find_univ2)
    if len(list_univ) > 0 :
        regex_match[row.rank_id]= "|".join(list_univ)
    else:
        pass
regex_match
df_adfr["etab"] = df_adfr.rank_id.map(regex_match.get)

# %%
t_etab = df_adfr[["id", "rank_id","etab"]]
t_etab["etab"] = t_etab.etab.str.split("|")
t_etab1 = t_etab.loc[~t_etab.etab.isna()].explode("etab").drop_duplicates().reset_index().drop(columns=["index"])
list_etab = [x for x in t_etab1.etab.unique()]
print(len(list_etab))
# Out:
# 2075
# /tmp/ipykernel_11041/1054126011.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_etab["etab"] = t_etab.etab.str.split("|")

# %%
file_path = BUCKET_OUT + "/" + "Data_bso/referentiels/fr-esr-principaux-etablissements-enseignement-superieur.csv"
with fs.open(file_path) as csvin:
    ref = pd.read_csv(csvin, sep =";")

ref.columns
# Out:
# Index(['etablissement_id_paysage', 'uo_lib', 'nom_court', 'sigle',
#        'type_d_etablissement', 'typologie_d_universites_et_assimiles',
#        'secteur_d_etablissement', 'vague_contractuelle', 'localisation', 'url',
#        'coordonnees', 'uai', 'anciens_codes_uai', 'siret', 'siren', 'rna',
#        'identifiant_wikidata', 'element_wikidata', 'identifiant_idref',
#        'identifiant_eter', 'identifiant_ror', 'element_ror', 'identifiant_pic',
#        'identifiant_orgref', 'identifiant_isni', 'element_isni',
#        'element_fundref', 'date_creation', 'texte_de_ref_creation_lib',
#        'texte_de_ref_creation', 'com_code', 'com_nom', 'uucr_id', 'uucr_nom',
#        'dep_id', 'dep_nom', 'aca_id', 'aca_nom', 'reg_id', 'reg_nom',
#        'reg_id_old', 'reg_nom_old', 'mention_distribution', 'adresse_uai',
#        'lieu_dit_uai', 'boite_postale_uai', 'code_postal_uai',
#        'localite_acheminement_uai', 'pays_etranger_acheminement',
#        'numero_telephone_uai', 'statut_juridique_court',
#        'statut_juridique_long', 'compte_facebook', 'compte_twitter',
#        'compte_instagram', 'compte_flickr', 'compte_pinterest', 'flux_rss',
#        'compte_linkedin', 'compte_france_culture', 'compte_scribd',
#        'compte_scoopit', 'compte_tumblr', 'compte_youtube', 'compte_vimeo',
#        'compte_dailymotion', 'compte_github', 'wikipedia', 'wikipedia_en',
#        'scanr', 'hal', 'mooc', 'article', 'uo_lib_officiel', 'uo_lib_en',
#        'url_en', 'url_cn', 'url_es', 'url_de', 'url_it',
#        'universites_fusionnees', 'etablissement_experimental',
#        'champ_recherche', 'inscrits', 'inscrits_2010', 'inscrits_2011',
#        'inscrits_2012', 'inscrits_2013', 'inscrits_2014', 'inscrits_2015',
#        'inscrits_2016', 'inscrits_2017', 'inscrits_2018', 'inscrits_2019',
#        'inscrits_2020', 'inscrits_2021', 'inscrits_2022'],
#       dtype='object')

# %%
cleaned_list_etab = [re.sub(r'\s+', ' ', re.sub(r"d'|l'|\bl\b|\bd\b|\bde\b|\bdes\b", " ", x)) for x in list_etab]


dict_etab = {}

for index, row in ref.iterrows():
    univ = re.sub(r"d'|l'|\bde\b|\bdes\b", " ",row.uo_lib.lower())
    cleaned_univ = re.sub(r'\s+', ' ', univ)
    #cleaned_list_etab = [re.sub(r'\s*', ' ', re.sub(r"d'|l'|\bde\b|\bdes\b", " ", x)) for x in list_etab]
    find_etab = [x for x in cleaned_list_etab if re.match(cleaned_univ, x)]
    for etab in find_etab:
        dict_etab[etab]= row.uo_lib

dict_etab
t_etab1["cleaned_etab"] = t_etab1.apply(lambda row: re.sub(r'\s+', ' ', re.sub(r"d'|l'|\bl\b|\bd\b|\bde\b|\bdes\b", " ", str(row.etab))),1)
t_etab1["norm_name"] = t_etab1.cleaned_etab.map(dict_etab.get)
t_etab1["id_rors"] = t_etab1.norm_name.map(dict(zip(ref.uo_lib, ref.identifiant_ror)).get)
#t_etab1["rors"] = "https://ror.org/" + t_etab1.id_rors.astype(str)
t_etab1
# Out:
#                      id rank_id  \
# 0       halhal-03933378       0
# 1       halhal-03933378       1
# 2       halhal-03933378       7
# 3       halhal-03933378       7
# 4       halhal-03933378       7
# ...                 ...     ...
# 118204  halhal-02120667   56314
# 118205  halhal-02120667   56315
# 118206  halhal-02120667   56315
# 118207  halhal-01964707   56316
# 118208  halhal-01964707   56316
#
#                                                      etab  \
# 0       institut national de recherches archéologiques...
# 1                                     université de tours
# 2                    université paris 1 panthéon-sorbonne
# 3                université paris 8 vincennes-saint-denis
# 4                         université 92023 nanterre cedex
# ...                                                   ...
# 118204                             université jean monnet
# 118205                                         université
# 118206                             la rochelle université
# 118207                          université paris lumières
# 118208           université paris 8 vincennes-saint-denis
#
#                                              cleaned_etab  \
# 0       institut national recherches archéologiques pr...
# 1                                        université tours
# 2                    université paris 1 panthéon-sorbonne
# 3                université paris 8 vincennes-saint-denis
# 4                         université 92023 nanterre cedex
# ...                                                   ...
# 118204                             université jean monnet
# 118205                                         université
# 118206                             la rochelle université
# 118207                          université paris lumières
# 118208           université paris 8 vincennes-saint-denis
#
#                      norm_name    id_rors
# 0                         None       None
# 1          Université de Tours  02wwzvj46
# 2                         None       None
# 3           Université Paris 8  04wez5e68
# 4                         None       None
# ...                        ...        ...
# 118204                    None       None
# 118205                    None       None
# 118206  La Rochelle Université  04mv1z119
# 118207                    None       None
# 118208      Université Paris 8  04wez5e68
#
# [118209 rows x 6 columns]

# %%
list_etab1 = list(set([x for x in t_etab1.etab.loc[t_etab1.id_rors.isna()]]))
print(len(list_etab1))
dict_ror2 = {}
for m, etab in tqdm.tqdm(enumerate(list_etab1), total = len(list_etab1)):
    row_id = m
    l_apostrophe = re.sub(r"\sl\s", " l'", etab)
    cleaned_etab = re.sub(r"\sd\s", " l'", l_apostrophe)
    response = requests.get(ROR_API_ENDPOINT + '?' + f'query="{cleaned_etab}"' + "&filter=country.country_code:fr").json()
    if response["number_of_results"] > 1 :
        for n, x in enumerate(response["items"]):
            if 'education' in x["types"] :
                datas = response["items"][n]
                rors = datas["id"]
    elif response["number_of_results"] == 1 :
        datas = response["items"][0]
        rors = datas["id"]
    else:
         rors = "not found"
    dict_ror2[etab] = rors
    #print(cleaned_etab, rors)
# Out:
# 1717
# 100%|██████████| 1717/1717 [03:12<00:00,  8.92it/s]

# %%
dict_ror2
# Out:
# {'labsic université': 'not found',
#  'université d¹evry val d¹essonne': 'not found',
#  'institut caennais de recherche juridique': 'https://ror.org/034p80033',
#  'umr 7317 cnrs et aix-marseille université': 'not found',
#  'école normale supérieure-psl du ministère de la culture du ministère des affaires étrangères': 'not found',
#  'université paris professeur à l institut': 'not found',
#  'institut d études ibériques et latino-américaines 31': 'not found',
#  'université abdou moumouni': 'not found',
#  'université marc bloch': 'not found',
#  'collège des bernardins': 'not found',
#  'ana portilla est doctorante en sociologie à l école': 'not found',
#  'université robert schuman': 'not found',
#  'université paris-1 paris france': 'not found',
#  'institut national de podologie': 'not found',
#  'institut de chimie organique et analytique': 'https://ror.org/03ywn7d79',
#  'university of paris 8 saint-denis cedex 02 france': 'not found',
#  'institut convergences migrations': 'not found',
#  'école normale supérieure': 'https://ror.org/04zmssz18',
#  'universiteit nijmegen': 'not found',
#  'universite de pau et des pays de l adour': 'https://ror.org/01frn9647',
#  'brain institut': 'not found',
#  'institut de recherche et documentation en economie de la santé': 'not found',
#  'au département d italien de l université': 'not found',
#  'maître de conférences-hdr à l université': 'not found',
#  'université de chambéry': 'https://ror.org/04gqg1a07',
#  'institut rayonnement matière de saclay': 'https://ror.org/00cch2r34',
#  'university paris diderot': 'not found',
#  'école polytechnique': 'https://ror.org/00szawm58',
#  'doctorant à l institut': 'not found',
#  'institut de biologie intégrative de la cellule': 'https://ror.org/01fftxe08',
#  'laboratoires de recherche de l école': 'not found',
#  'ethics ea 7446université': 'not found',
#  'universitaires du septentrion': 'not found',
#  'université de paris ouest nanterre la défense': 'not found',
#  'école nationale supérieure d architecture de bretagne': 'not found',
#  'senior fellow à l institut': 'not found',
#  'france maître de conférences en psychologie université': 'not found',
#  'institut d electronique et des systèmes': 'not found',
#  'universitaires de france presses universitaires france': 'not found',
#  'il est chercheur invité à l institut de sociologie de l université de neuchâtel et à l institut': 'not found',
#  'institut godin': 'not found',
#  'institut néel': 'https://ror.org/04dbzz632',
#  'susan ball is senior lecturer in contemporary british civilisation at the university': 'not found',
#  'université lyon 2': 'not found',
#  'université paris ouest nanterre la défense 200 av': 'not found',
#  'il est docteur en sociologie de l école': 'not found',
#  'aux presses universitaires': 'not found',
#  'maison rené ginouvès umr 7041 21 allée de l université': 'not found',
#  'plateforme universitaire': 'not found',
#  'universitaire72000 le mans': 'not found',
#  'institut': 'https://ror.org/01dkyve95',
#  'université paris diderot': 'not found',
#  'université mcgill': 'not found',
#  'umr 8533 cnrs   université': 'not found',
#  'institut d histoire des représentations et des idées dans les modernités': 'not found',
#  'savoirs et sociétés université': 'not found',
#  'institut de génétique humaine 141 rue de la cardonille 34396 montpellier cedex 5': 'not found',
#  'universite paris 8': 'https://ror.org/04wez5e68',
#  'university of sorbonne paris north': 'https://ror.org/0199hds37',
#  'universite paris 1 pantheon-sorbonnemaison des sciences économiques106-112 boulevard de l hôpital75647 paris cedex 13': 'not found',
#  'université catholique de lille60 boulevard vauban59000 lille': 'not found',
#  'institut du désert et des steppes': 'not found',
#  'maître de conférences umr lavue université': 'not found',
#  'university paris-est créteil': 'not found',
#  'lunam université': 'not found',
#  'universite paris 8 ufr de psychologie': 'not found',
#  'université d evry-val-d essonneboulevard françois mitterrand91025 evry cedex': 'not found',
#  'université jean monnetsite tréfilerie': 'not found',
#  'institut de l ouest': 'https://ror.org/030ewzw66',
#  'transferts critiques et dynamique des transferts critiques et dynamique université': 'not found',
#  'université montesquieu': 'not found',
#  'doctorante en études de genre et de sexualité   sociologie à l université': 'not found',
#  'universities': 'https://ror.org/043rxf076',
#  'institut marcel mauss': 'https://ror.org/02c5gbd66',
#  'institut des matériaux de cergy-pontoise': 'not found',
#  'university professor': 'not found',
#  'docteur hdr en géopolitique de l institut': 'not found',
#  'université paris 1 panthéon-sorbonne et chercheuse à l idhe': 'not found',
#  'institut jean le rond d alembert': 'not found',
#  'institut agro dijon': 'https://ror.org/03zek0r74',
#  'institut pierre louis d epidémiologie et de santé publique': 'not found',
#  'puis lors de son doctorat à l université de montréal et l université': 'not found',
#  'école nationale des chartes': 'https://ror.org/013xvg556',
#  'de la région île-de-france décernée par l institut': 'not found',
#  'iae nancy school': 'not found',
#  'institut de géographie': 'not found',
#  'école centrale paris': 'not found',
#  'university of paris 8 93526 saint-denis france': 'not found',
#  'écoles': 'https://ror.org/042949r55',
#  'de la jeunesse et des sports du kosovo école': 'not found',
#  'benjamin fiorini est maître de conférences en droit privé et sciences criminelles à l université': 'not found',
#  'école nationale supérieure d architecture paris val-de-seine crh': 'not found',
#  '57045 metz cedexuniversité': 'not found',
#  'maître de conférences en études sur la stratégie et la guerre à l institut français de géopolitique de l université': 'not found',
#  'institut national de recherche en informatique et en automatique': 'https://ror.org/02kvxyf05',
#  'institut français de géopolitique de l université paris-viii': 'not found',
#  'universitaire': 'https://ror.org/03f099r71',
#  'université paul-valéry montpellier 3': 'not found',
#  'université paris 1-panthéon sorbonne': 'https://ror.org/002t25c44',
#  'aix marseille université': 'https://ror.org/035xkbk20',
#  'université françois-rabelais': 'not found',
#  'institut élie cartan de lorraine': 'https://ror.org/04rvw8791',
#  'university management lab': 'not found',
#  'institut de recherche et coordination acoustique': 'https://ror.org/0121jnt59',
#  'collège international de philosophie': 'not found',
#  'cnrs-laga université paris 13 cnrs laga université': 'not found',
#  'école centrale de marseille': 'https://ror.org/040baw385',
#  'école nationale supérieure d architecture de paris la villette': 'not found',
#  'univ': 'https://ror.org/015m7wh34',
#  'laboratoire d acoustique de l université': 'not found',
#  'university of paris ouest-nanterre 200 avenue de la republique 92001 nanterre cedex france': 'not found',
#  'université libre de bruxelles': 'not found',
#  'faculté d education de l université': 'not found',
#  'institutions et dynamiques historiques de l economie': 'https://ror.org/03p76m698',
#  'université paris-x nanterre': 'not found',
#  'institut pierre renouvin 1': 'not found',
#  'universitésite chênes 233': 'not found',
#  'cresppa université': 'not found',
#  'polina manko est diplômée de master en arts du spectacle vivant de l université': 'not found',
#  'umr 8533 cnrs et université': 'not found',
#  'université paris': 'https://ror.org/013cjyk83',
#  'il est membre de l institut universitaire': 'not found',
#  'universite paris 2': 'not found',
#  'indiana university': 'not found',
#  'université paris 13 sorbonne paris cité cnrs 93430 villetaneuse france': 'not found',
#  'arscan -21 allée de l université': 'not found',
#  'teikyo university': 'not found',
#  'she is now an assistant professor of second language acquisition in the english department of université': 'not found',
#  'institute and led': 'not found',
#  'université d evry val d essonne': 'not found',
#  'dvrc pôle universitaire': 'not found',
#  'professeur d histoire-géographie affecté à l institut universitaire': 'not found',
#  'université de paris ouest': 'not found',
#  'collège universitaire': 'not found',
#  'université de cologne': 'not found',
#  'université de paris université de paris': 'not found',
#  'cnrs -université paris 8 cnrs université': 'not found',
#  'christine delory-momberger est professeure émérite en sciences de l éducation à l université': 'not found',
#  'france  ethnologie préhistorique and centre de recherche et de documentation sur l océanie university': 'not found',
#  'dhn-collège': 'not found',
#  'univ-paris8': 'not found',
#  'universitaire du pont de bois': 'not found',
#  'école de droit': 'https://ror.org/02nwb8925',
#  'de l université': 'https://ror.org/035hv2v80',
#  'institut claude de préval': 'not found',
#  'université michel de montaigne-bordeaux 3 et membre de l équipe de recherche mica': 'not found',
#  'intermédiaires et consécration dans les univers': 'not found',
#  'maître de conférences laboratoire lavue université': 'not found',
#  'universud': 'not found',
#  'université de nice sophia-antipolis': 'not found',
#  'institut supérieur des beaux-arts de besançon': 'https://ror.org/02z87sy46',
#  'école nationale supérieure de chimie et de physique de bordeaux': 'not found',
#  'university of paris': 'https://ror.org/03xjwb503',
#  'institut de recherche sur l antiquité et le moyen âge': 'https://ror.org/05jm22562',
#  'institut français de l education': 'https://ror.org/04tmh0n51',
#  'institut historique allemand': 'https://ror.org/02f1mqt91',
#  '44312 nantes cedex 03université': 'not found',
#  'france laboratoire laga umr 7539 cnrs université': 'not found',
#  'institut supérieur des sciences agronomiques': 'https://ror.org/01s3fs709',
#  'institut de recherche sur la fusion par confinement magnétique': 'https://ror.org/03hffat62',
#  'univers de rennes': 'not found',
#  'institut de sociologie de l université de neuchâtel et à l institut de recherche sociale de francfort': 'not found',
#  'université d évry-val d essonne': 'not found',
#  'labtop keivan djavadzadeh est doctorant en science politique à l université': 'not found',
#  'université paris diderotufr ghss': 'not found',
#  'martine beugnet est professeure en études visuelles à l ufr d études anglophones de l université': 'not found',
#  'institut d histoire de la philosophie': 'not found',
#  'laboratoire experice université': 'not found',
#  'université campus joseph aiguier 31 chemin joseph aiguier 13402 marseille cedex 20': 'not found',
#  'école nationale vétérinaire': 'https://ror.org/05q0ncs32',
#  'henri desbois est maître de conférences en géographie à l université': 'not found',
#  'université paris est créteil': 'https://ror.org/05ggc9x40',
#  'université de cergy-pontoise 5 mail gay-lussac 95031 cergy-pontoise': 'not found',
#  'institut de recherche juridique interdisciplinaire': 'https://ror.org/0576vz251',
#  'institut de recherche sur les systèmes atomiques et moléculaires complexes': 'not found',
#  'université paris-diderot': 'not found',
#  'institut d ergologie': 'not found',
#  'directeur du département d études arabes université': 'not found',
#  'université paris 1 panthéon-sorbonne umr 7041 archéologie et sciences de l antiquité protohistoire égéenne archéologie et sciences de l antiquité protohistoire égéenne umr 7041 université paris 1 panthéon-sorbonne': 'not found',
#  'lilpa université': 'not found',
#  'école de sages-femmes baudelocque': 'not found',
#  'institutions et des organisations': 'not found',
#  'ufr stapsuniversité': 'not found',
#  'université paris saclay': 'https://ror.org/03xjwb503',
#  'european school': 'https://ror.org/05eyymj94',
#  'institute of animal sciences': 'not found',
#  'france normandie univ': 'not found',
#  'université paris ouest': 'https://ror.org/013bkhk48',
#  'devenu en 2016 une unité mixte de recherche associant le cnrs et l université': 'not found',
#  'membre du bureau de cette université': 'not found',
#  'université de paris-viii': 'https://ror.org/04wez5e68',
#  'universitaire de psychologie': 'https://ror.org/03jrb0276',
#  'université paul valéry montpellier 3route de mende 34199 montpellier cedex 5': 'not found',
#  'institut de droit public': 'not found',
#  'université paris-sorbonne': 'not found',
#  'série de vidéos d actualité du droit pénal réalisées par les étudiants de l université': 'not found',
#  'université paris laboratoire d économie dionysien-led': 'not found',
#  'university of paris ouest-nanterre': 'not found',
#  'il est actuellement doctorant contractuel en sciences de l information et de la communication à l université': 'not found',
#  'il dirige l institut': 'not found',
#  'laboratoire universitaire': 'https://ror.org/00y523k32',
#  'institut de recherche mathématique de rennes': 'https://ror.org/05y76vp22',
#  'institut de médecine intégrative et complémentaire': 'not found',
#  'institut polytechnique de bordeaux': 'https://ror.org/054qv7y42',
#  'emlyon business school': 'https://ror.org/009gmrj52',
#  'universitaire expérience ressources culturelles éducation ea3971': 'not found',
#  'ea 3456université': 'not found',
#  'elle est professeure des universités à l institut': 'not found',
#  'université de paris i panthéon sorbonne': 'not found',
#  'school of political and social sciences': 'not found',
#  'laboratoire interuniversitaire': 'not found',
#  'ancien élève de l école normale supérieure de cachan et de l institut': 'not found',
#  'institut de biologie et chimie des protéines': 'not found',
#  'université': 'https://ror.org/03z6jp965',
#  'montpellier business school': 'https://ror.org/037tw3m02',
#  'céreq-eso université': 'not found',
#  'institution paris 2015 questions théoriques': 'not found',
#  'applica-tions umr 7539 université': 'not found',
#  'institutions et sociétés': 'not found',
#  'université 1': 'not found',
#  'universitaire d angers': 'not found',
#  'institut du droit de l espace': 'https://ror.org/047kfvz78',
#  'avenue de l université': 'not found',
#  'institut de psychologie': 'not found',
#  'institut pasteur': 'not found',
#  'université françois-rabelais de tours 3': 'not found',
#  'université paris nord': 'not found',
#  'institut lyfe': 'not found',
#  'univ-paris-diderot': 'not found',
#  'universitaire de besançon': 'https://ror.org/0084te143',
#  'école primaire ruvoletto samantha université paris 8': 'not found',
#  'institut denis poisson': 'https://ror.org/05djhd259',
#  'universit e': 'not found',
#  'presses universitaires': 'not found',
#  'institut d histoire et de philosophie des sciences et des techniques': 'not found',
#  'école universitaire': 'not found',
#  'universitaire robert debré': 'not found',
#  'université de prishtina et de l institut archéologique du kosovo': 'not found',
#  'université paris doctorant en archéologie du monde égéen université paris': 'not found',
#  'institut de chimie': 'https://ror.org/041yg4h55',
#  'université paris ouest nanterre université paris ouest nanterre': 'not found',
#  'université de franche-comté': 'not found',
#  'west paris university': 'not found',
#  'docteur hdr de l université': 'not found',
#  'école nationale supérieure agronomique de toulouse': 'https://ror.org/03d5w9863',
#  'enseignant en questions internationales à sciences po paris et à la paris school': 'not found',
#  '21 all ee de l universit': 'not found',
#  'university of paris 8 and paris 13': 'not found',
#  'soutenue à l université': 'not found',
#  'professeur invitée à el colegio de méxico professeur émérite de démographie université': 'not found',
#  'institut neel': 'https://ror.org/04dbzz632',
#  'enseignant au département culture et communication de l université': 'not found',
#  'université paris-est-créteil': 'https://ror.org/05ggc9x40',
#  'institut français napoli': 'not found',
#  'institut d études européennes et membre honoraire de l institut universitaire': 'not found',
#  'institut d etudes européennes': 'not found',
#  'université de paris ufr ghes inégalités sociales': 'not found',
#  'and member of the research group transcrit at the university': 'not found',
#  'universitaire de tours': 'https://ror.org/00jpq0w62',
#  'laga université': 'not found',
#  'institut universitaire europe': 'not found',
#  'université 35': 'not found',
#  'université de lausanne and sorbonne université': 'not found',
#  'université paris 1399': 'not found',
#  'university of paris 8 93526 saint-denis': 'not found',
#  'institut montaigne': 'not found',
#  'institut de génétique moléculaire de montpellier': 'https://ror.org/02785qs39',
#  'université degli studi di firenze': 'not found',
#  'université paris 1 panthéon sorbonne': 'https://ror.org/002t25c44',
#  'école nationale de la statistique et de l administration économique': 'https://ror.org/01fz7mn40',
#  'université henri poincaré': 'not found',
#  'universitaire expérience ressources culturelles éducation-experice': 'not found',
#  'centre universitaire': 'https://ror.org/03078mv10',
#  'brussels free university': 'not found',
#  'université lumière': 'https://ror.org/03rth4p18',
#  'institut d urbanisme de lyon': 'not found',
#  'institut camille jordan': 'https://ror.org/01ekw7f87',
#  'institut national des sciences de l univers': 'https://ror.org/04kdfz702',
#  'université panthéon assas': 'https://ror.org/04qb2qm38',
#  'université de paris-sud': 'not found',
#  'institut des sciences humaines et sociales': 'https://ror.org/04b0z7q78',
#  'université catholique de lille f-59000 lille france': 'not found',
#  'france school': 'not found',
#  'université paul-valéry': 'not found',
#  'laboratoire de psychopathologie et de neuropsychologie universite': 'not found',
#  'université paris l encyclopédie des guerres de jean-yves jouannais adrien chassain université': 'not found',
#  'school of mechanical and manufacturing engineering': 'not found',
#  'member of the president s board of this university': 'not found',
#  'université de valenciennes et du hainaut-cambrésis': 'not found',
#  'université paris 13 campus de bobigny 74 rue marcel cachin 93017 bobigny cedex': 'not found',
#  'institut de recherche sur l education': 'https://ror.org/019qdtz78',
#  'université de toulouse jean jaurès': 'not found',
#  'université paris dauphine-psl': 'https://ror.org/052bz7812',
#  'école doctorale de sciences sociales -université paris 8 courriel école doctorale de sciences sociales université paris 8 courriel': 'not found',
#  'rennes university': 'not found',
#  'university': 'https://ror.org/03hypw319',
#  '1 paris 8 university': 'not found',
#  'lyon catholic university': 'https://ror.org/01anhj553',
#  'institut acte': 'https://ror.org/05hne2921',
#  'instituto de biociências de botucatu': 'not found',
#  'université nice sophia antipolis campus saint-jean-d angély': 'not found',
#  'université paris 13': 'https://ror.org/0199hds37',
#  'collège international de recherche biographique en éducation': 'not found',
#  'université paris-ouest nanterre-la défense et membre du lavue': 'not found',
#  'professeure de sociologie université': 'not found',
#  'université paris 1': 'https://ror.org/002t25c44',
#  'université laval': 'not found',
#  'à l institut universitaire': 'not found',
#  'samantha université': 'not found',
#  'université de paris 1': 'not found',
#  'institut télécom-télécom bretagne': 'not found',
#  'professeure associée cornell university': 'not found',
#  'université d évry-val d essonne paris-saclay': 'not found',
#  'école doctorale d archéologie': 'not found',
#  'université de naples': 'not found',
#  'university paris liasd -university paris': 'not found',
#  'universitaire de rennes': 'https://ror.org/05qec5a53',
#  'université panthéon-assas': 'https://ror.org/04qb2qm38',
#  'chercheuse en postdoctorat et cheffe de projet au sein du centre de recherche et de formation geode de l université': 'not found',
#  'institut des sciences de l homme': 'not found',
#  'université paris université': 'not found',
#  'université paris 13 sorbonne paris cité': 'not found',
#  'université européenne de bretagne': 'not found',
#  'université d abidjan-cocody': 'not found',
#  'doctorante en archéologie université': 'not found',
#  'université paul valéry montpellier 3': 'not found',
#  'universitaire des sciences de l homme': 'not found',
#  'institut national d étude du travail et d orientation professionnelle': 'not found',
#  'universite paris 8 departement humanites numeriques': 'not found',
#  'université paris est creteil': 'https://ror.org/05ggc9x40',
#  'universitaires de strasbourg': 'https://ror.org/05ggc9x40',
#  'institut des sciences sociales du politique': 'https://ror.org/03jdg7625',
#  'auriane guilbaud est maîtresse de conférences en science politique à l institut d études européennes de l université': 'not found',
#  'universitaires de paris nanterre editore presses universitaires de paris nanterre': 'not found',
#  'institut des sciences du vivant frédéric joliot': 'https://ror.org/016pnwd02',
#  'geneviève sellier est professeure en études cinématographiques à l université': 'not found',
#  'centre d economie de l université': 'not found',
#  'doctorant en sociologie à l université': 'not found',
#  'réalisée à l université': 'not found',
#  'universitaires de paris nanterre': 'not found',
#  'institut terre environnement strasbourg': 'not found',
#  'universités paris 8 et upec': 'not found',
#  'institut parisien de recherche architecture urbanistique société': 'not found',
#  '4 rue elsa morante 75013 paris -université': 'not found',
#  'université de cergy-pontoise-espe-site de gennevilliers- zac des barbanniers': 'not found',
#  'institut de radioprotection et de sûreté nucléaire': 'not found',
#  'school of mechanical and manufacturing engineering supmeca-paris france': 'not found',
#  'éditions presses universitaires de france presses éditions presses universitaires': 'not found',
#  'institut d études politiques fontainebleau': 'not found',
#  'école nationale supérieure d architecture de nantes': 'not found',
#  'université paris 79': 'not found',
#  'université paris 13 université paris 13': 'not found',
#  'institut universitaire de france et présidente de l  afeccav': 'not found',
#  'palais universitaire': 'not found',
#  'benoit gautier est doctorant en sociologie du travail à l université': 'not found',
#  'école doctorale edesta   esthétique': 'not found',
#  'institut photonique d analyse non-destructive européen des matériaux anciens': 'not found',
#  'institut français d études anatoliennes-istanbul': 'not found',
#  'university of poitiers': 'https://ror.org/04xhy8q59',
#  'jeanne demoulin est docteure en aménagement de l espace et urbanisme de l université': 'not found',
#  'universitat de barcelona legs-paris 8-vincennes-saint dennis adhuc-universitat de barcelona legs-paris 8-vincennes-saint dennis': 'not found',
#  'institut de recherche intersite études culturelles': 'https://ror.org/02ygx5k49',
#  'école des ponts paristech': 'https://ror.org/02nwvxz07',
#  'institut national de la jeunesse et de l education populaire à marly': 'not found',
#  'école supérieure des géomètres et topographes': 'https://ror.org/04e71td73',
#  'bâtiments 650-660 université': 'not found',
#  'institut d administration des entreprises de franche comté': 'not found',
#  'universite pierre et marie curie paris vi 9': 'not found',
#  'institut galilée': 'not found',
#  'école nationale supérieure d architecture et du paysage de bordeaux': 'not found',
#  'verimagbâtiment imaguniversité': 'not found',
#  'école de travail social et de la santé': 'not found',
#  'université paris 1 panthéon-sorbonne gllmpetit': 'not found',
#  'maître de conférences en science politique à l université': 'not found',
#  'université paris-3 sorbonne nouvelle': 'not found',
#  'institut d histoire de la pensée classique': 'not found',
#  'institut des sciences de l homme 14 avenue berthelot 69363 lyon cedex 07': 'not found',
#  'france ladyss umr 7533 cnrs sorbonne paris cité university': 'not found',
#  'université de nantes': 'https://ror.org/03gnr7b55',
#  'institut d études politiques de lyon': 'not found',
#  'lettres et languesuniversité': 'not found',
#  'hôpital universitaire': 'not found',
#  'institut du droit public et de la science politique': 'https://ror.org/05nn1k450',
#  'institut d études européennes alain quemin est professeur de sociologie de l art à l université paris-8': 'not found',
#  'université paris-ouest nanterre et anr dhell université': 'not found',
#  'université paris 12': 'not found',
#  'université paris 13 -sorbonne paris cité': 'not found',
#  'lavue -cnrs école': 'not found',
#  'institut des sciences moléculaires d orsay': 'not found',
#  'france professeur des universités': 'not found',
#  'institut d études européennes alain quemin est professeur de sociologie de l art à l université': 'not found',
#  'et à l université': 'not found',
#  'maîtresse de conférences en littérature à l université': 'not found',
#  'professeure d histoire contemporaine à l université': 'not found',
#  'institut de recherche en musicologie': 'https://ror.org/04gf9wd48',
#  'membre du centre de recherche interuniversitaire': 'not found',
#  'université paris est créteil val de marne  immeuble la pyramide  bureau 405 lirtes équipe d accueil 7313 80 avenue du général de gaulle 94009 créteil cedex': 'not found',
#  'à l université': 'not found',
#  'et actuellement en délégation à l institut': 'not found',
#  'university management -- iae lille': 'not found',
#  'institut de recherche juridique de la sorbonne andré tunc': 'not found',
#  'institut de la gestion publique et du développement économique': 'not found',
#  'institut de recherches en etudes théâtrales': 'not found',
#  'institut de biologie paris seine': 'https://ror.org/01c2cjg59',
#  'école des mines de douai': 'not found',
#  'marlène coulomb-gully est professeure à l université': 'not found',
#  'institut de santé publique': 'not found',
#  'école normale supérieure de cachan': 'not found',
#  '1 rue honoré d estienne d orvesbâtiment alan turingcampus de l école': 'not found',
#  'institut de chimie et des matériaux paris-est': 'https://ror.org/04c3cen15',
#  'institut interdisciplinaire d anthropologie du contemporain': 'not found',
#  'institut de démographie de l université paris 1': 'not found',
#  'école universitaire de recherche artec': 'not found',
#  'institut universitaire de technologie': 'https://ror.org/03zav0w05',
#  'université paul valéry montpellier 3 route de mende 34199 montpellier cedex 5': 'not found',
#  'universalité': 'https://ror.org/0347ywk92',
#  'institut d administration des entreprises': 'not found',
#  'université f 92023 nanterre cedex': 'not found',
#  'il est membre senior de l institut universitaire': 'not found',
#  'associate professor in economics university': 'not found',
#  '2019 linx revue des linguistes de l université': 'not found',
#  'institut national de l horticulture et du paysage': 'not found',
#  'université paris-seine': 'not found',
#  'institut de recherche en gestion et en economie': 'not found',
#  'institut kheops': 'not found',
#  'université paris-diderot et chercheur en économie et anthropologie sociale': 'not found',
#  'membre honoraire de l institut universitaire': 'not found',
#  'university paris-diderot': 'not found',
#  'communauté université': 'not found',
#  'géométrie et applications université': 'not found',
#  'paris laga université': 'not found',
#  'university of paris 8 university of paris 13 cnrs umr 7539 laga and telecom paristech paris france': 'not found',
#  'université libre de bruxelles et se spécialise également en analyse du mouvement': 'not found',
#  'institut photovoltaïque d ile-de-france': 'not found',
#  'école doctorale d histoire de l université paris 1 panthéon-sorbonne': 'not found',
#  'université de lausanne dans le cadre d une recherche': 'not found',
#  'université lumière lyon 2 5 avenue pierre mendès france 69676 bron cedex': 'not found',
#  'institut de recherche interdisciplinaire homme et société': 'not found',
#  'professeure de philosophie à l école nationale supérieure d architecture de paris la villette et directrice de programme au collège': 'not found',
#  'la rochelle business school': 'https://ror.org/051gb6s93',
#  'institut universitaire de france': 'https://ror.org/055khg266',
#  'institut universitaire européen de la mer': 'https://ror.org/04pfr1b11',
#  'institut de recherche en sciences de l information et de communication': 'not found',
#  'école centralesupelec': 'not found',
#  'école nationale supérieure des mines d albi-carmaux': 'not found',
#  'institut national universitaire': 'not found',
#  'liasd -university paris liasd -university': 'not found',
#  'université avenue olivier messiaen 72085': 'not found',
#  'paris université': 'https://ror.org/013pnfx92',
#  'institut dolomieu et maison des géosciences': 'not found',
#  'institutions et stratégies d acteurs': 'not found',
#  'centre interuniversitaire': 'not found',
#  'institut de recherche en propriété intellectuelle': 'https://ror.org/03npdj196',
#  'institut français de naples 86 via crispi naples': 'not found',
#  'universitaires de rennes': 'not found',
#  'université claude bernard': 'https://ror.org/029brtt94',
#  'montpellier university': 'https://ror.org/03vba6259',
#  'universitaire d etudes françaises': 'not found',
#  'institut galilée laga université': 'not found',
#  'lapps université': 'not found',
#  'institut jean vigo': 'not found',
#  'deutsches historisches institut': 'https://ror.org/02f1mqt91',
#  'institut d études européennes institut d études européennes université paris 8 2': 'not found',
#  'insa institut': 'not found',
#  '72085 le mans cedex 09université': 'not found',
#  'université paris 13 99 avenue jean baptiste 93430 clément': 'not found',
#  'institut de recherche technologique systemx': 'https://ror.org/03crmsn52',
#  'university paris 8-led': 'not found',
#  'école des hautes études en sciences de l information et de la communication': 'not found',
#  'université catholique de lillef-59000 lillefrance': 'not found',
#  'paris nanterre university': 'https://ror.org/013bkhk48',
#  'università degli studi di roma': 'not found',
#  'institut de biologie de l ens paris': 'not found',
#  'université paris 2': 'not found',
#  'university level': 'not found',
#  'cnrs-université paris 8 vincennes saint-denis-université': 'not found',
#  'institut de physique nucléaire d orsay': 'not found',
#  'université michel de montaigne domaine universitaire': 'not found',
#  'institut supérieur de commerce international de dunkerque côte d opale': 'not found',
#  'école nationale supérieure d architecture de paris val-de-seine': 'not found',
#  'institut des sciences et techniques de l antiquité': 'https://ror.org/00gy9rx06',
#  'bureau 405université': 'not found',
#  'institut des sciences de l evolution de montpellier': 'https://ror.org/01cah1n37',
#  'cresppa-csu université paris 8 saint-denis université': 'not found',
#  'université paris-nanterre et université': 'not found',
#  'institut national d études supérieures agronomiques de montpellier': 'not found',
#  'université92023 nanterre cedex': 'not found',
#  'campus de la doua université': 'not found',
#  'institut des textes et manuscrits modernes': 'https://ror.org/00x1d4q78',
#  'ea3388 docteur en sciences de l information et de la communication université': 'not found',
#  'université paris sud': 'not found',
#  'école nationale supérieure d architecture de languedoc-rousillon': 'not found',
#  'université paris-nanterre': 'https://ror.org/013bkhk48',
#  'institut d histoire du droit jean gaudemet': 'not found',
#  'université paris 1 panthéon-sorbonne 90 rue de tolbiac 75013 paris pays fr': 'not found',
#  'comue université': 'not found',
#  'institut agro': 'https://ror.org/01s3fs709',
#  'institut de recherches philosophiques de lyon': 'https://ror.org/01k6ebg12',
#  'university of paris 8': 'not found',
#  'université blaise-pascal de clermont-ferrand': 'not found',
#  'institut gustave roussy': 'https://ror.org/0321g0743',
#  'mines ales école': 'not found',
#  'habilité à diriger des recherches de l université': 'not found',
#  'cnrs umr 7023 sfl umr 7023 sfl université': 'not found',
#  'institut national de recherche pour l agriculture': 'https://ror.org/003vg9w96',
#  'université93023 nanterre cedex': 'not found',
#  'university 7074': 'not found',
#  'université lyon 3 et publiée en décembre 2018 aux éditions lgdj et a notamment exercé la fonction de juriste assistant auprès des juges d instruction du tj de boulogne-sur-mer': 'not found',
#  'university hospital': 'not found',
#  'institut de planétologie et d astrophysique de grenoble': 'not found',
#  'ulrike lune riboni université': 'not found',
#  'institut supérieur de management': 'not found',
#  'panthéon-sorbonne university': 'https://ror.org/002t25c44',
#  '4 route de choisy 94010 créteil cedexuniversité': 'not found',
#  'institut de recherche en sciences de l information et de communication21': 'not found',
#  'universitaire de developpement social et emotionnel': 'not found',
#  'domaine universitaire': 'not found',
#  'il est actuellement doctorant à l université': 'not found',
#  'institut national de physique nucléaire et de physique des particules du cnrs': 'not found',
#  'université paris-viii': 'https://ror.org/04wez5e68',
#  'centre de recherche des cordeliers15 rue de l école': 'not found',
#  'magis est maître de conférences en sciences de l information et de la communication à l université': 'not found',
#  'laboratoire paragraphe université': 'not found',
#  'ea 1571 centre de recherches historiques université': 'not found',
#  'institut de la communication et des médias 11 avenue du 8 mai 1945 bp 337': 'not found',
#  'institut brestois du numérique et des mathématiques': 'not found',
#  'maitre de conférences université': 'not found',
#  'l institut': 'not found',
#  'cnrs and university': 'not found',
#  'université toulouse le mirail': 'not found',
#  'ed112 université paris 1 panthéon-sorbonne umr 7041 archéologie et sciences de l antiquité protohistoire égéenne archéologie et sciences de l antiquité protohistoire égéenne umr 7041 université': 'not found',
#  'umr 7320mshs sud-est pôle universitaire': 'not found',
#  'institut national de prévention et d education pour la santé': 'not found',
#  'france department of anthropology university': 'not found',
#  'institut des procédés appliqués aux matériaux': 'not found',
#  'university of paris 8 2 rue de la liberté 93526 saint-denis cedex france': 'not found',
#  'maría ignacia alcalá sucre est doctorante en sciences de l information et de la communication à université': 'not found',
#  'sébastien lemerle est maître de conférences hdr en sociologie à l université': 'not found',
#  'présidente du collège': 'not found',
#  'leme ea4416université': 'not found',
#  'university of quebec at montreal': 'not found',
#  'laga university': 'not found',
#  'university of paris vii diderot ufr social sciences': 'not found',
#  'paris school': 'https://ror.org/05rdkc048',
#  'universidade sorbonne paris nord -paris 13 centro interuniversitário experice universidade sorbonne paris nord paris 13 centro interuniversitário experice': 'not found',
#  'maître de conférences à l  laboratoire mosaiques umr lavue université': 'not found',
#  'institut des maladies métaboliques et cardiovasculaires': 'not found',
#  'institut de science des matériaux de mulhouse': 'not found',
#  'université paris-descartes45 rue des saints-pères75006 parisfrance': 'not found',
#  'bertrand warusfel est professeur de droit à l université': 'not found',
#  'université paris-ouest-nanterre-la défense': 'https://ror.org/013bkhk48',
#  '93 526 saint-denis chercheur associé maître de conférences en géographie umr 7533 ladyss -2 université': 'not found',
#  'institut supérieur de mécanique de paris': 'https://ror.org/04dtfqt68',
#  'francia université': 'not found',
#  'cedex 2université': 'not found',
#  'université31 chemin joseph-aiguiercs 7007113402 marseille cedex 20': 'not found',
#  'université de cocody': 'not found',
#  'france cresppa-gtm université': 'not found',
#  'école nationale supérieure d architecture de paris la villette et directrice de programme au collège international de philosophie': 'not found',
#  'university of brest and university': 'not found',
#  'université paris-sud': 'not found',
#  'université paris-ouest -nanterre université': 'not found',
#  'universités': 'not found',
#  'institut des amériques': 'not found',
#  'école des officiers de la gendarmerie nationale': 'https://ror.org/05kqgwz20',
#  'institut de recherche sur les archéomatériaux iramat': 'not found',
#  'khedidja mamou est ater à l institut': 'not found',
#  'institut de recherche sur l architecture antique': 'https://ror.org/03r0cdk24',
#  'université numérique paris ile-de-france': 'not found',
#  'université de savoie': 'not found',
#  'école normale supérieure paris-saclay gif-sur-yvette france': 'not found',
#  'university paris ouest nanterre la défense': 'not found',
#  'institut galilée laboratoire analyse': 'not found',
#  'experice université': 'not found',
#  'institut de recherches économiques et sociales': 'https://ror.org/04mb2v544',
#  'institut de recherche stratégique de l ecole militaire': 'not found',
#  'institut national polytechnique': 'https://ror.org/033p9g875',
#  'sabine effosse est professeur d histoire contemporaine à l université': 'not found',
#  '1 normandie univ': 'not found',
#  'université paris-ouest -nanterre université paris-ouest -nanterre': 'not found',
#  'institute im ausland': 'not found',
#  'cergy paris université': 'https://ror.org/043htjv09',
#  's université': 'not found',
#  'en cinéma à l université paris 8 vincennes-saint-deniset membre junior de l institut universitaire': 'not found',
#  'université de cergy pontoise': 'not found',
#  'de paul university': 'not found',
#  'université de parisbâtiment sophie germain': 'not found',
#  'étudiante de licence musique de l université': 'not found',
#  'université paris ouest nanterre-la défense': 'https://ror.org/013bkhk48',
#  'institut interdisciplinaire de l innovation': 'https://ror.org/00mz87608',
#  'université de lausanne 11 rue de l industrie': 'not found',
#  'université paris diderot irem de paris': 'not found',
#  'institut de signalisation': 'not found',
#  'institut de myologie': 'https://ror.org/0270xt841',
#  'cnrs university': 'not found',
#  'franceuniversité': 'not found',
#  'universitaires d oxford': 'not found',
#  'institutions et société de la rome antique': 'not found',
#  'institut français de recherche sur l asie de l est': 'https://ror.org/00ngq1v76',
#  'paris 8 vincennes-univ': 'not found',
#  's univ evry université': 'not found',
#  'institut de recherche en infectiologie de montpellier': 'https://ror.org/036eg1q44',
#  'université d auvergne': 'not found',
#  'departments of german studies and political science university': 'not found',
#  'cornell university': 'not found',
#  'institut mondor de recherche biomédicale': 'https://ror.org/04qe59j94',
#  'umr cnrs paris nanterre university': 'not found',
#  'docteur en géographie humaine de l université': 'not found',
#  'institut des mondes anglophones': 'not found',
#  'cnrs--université': 'not found',
#  'université paris ouest idhe france': 'not found',
#  'université paris-ouest nanterre': 'https://ror.org/013bkhk48',
#  'institut national de recherche en sciences et technologies pour l environnement et l agriculture': 'not found',
#  'institut français de géopolitique de l université paris 8 vincennes': 'not found',
#  '57493 université': 'not found',
#  'doctorant à l université': 'not found',
#  'institut interdisciplinaire de l innovation de telecom paris': 'not found',
#  'mcgill university': 'not found',
#  'école nationale supérieure d architecture de nancy': 'not found',
#  'agence universitaire': 'not found',
#  'institut entreprise et personnel bénéficiaires de contrats cifre': 'not found',
#  'pole universitaire': 'https://ror.org/02setav13',
#  'institut émilie du châtelet': 'not found',
#  'institut de chimie moléculaire et des matériaux d orsay': 'not found',
#  'institut parisien de chimie moléculaire': 'https://ror.org/04qwfwm19',
#  'institut agro dijon26 boulevard dr petitjean bp 8799921079 dijon cedex': 'not found',
#  'école des mines d alès': 'not found',
#  'université paris 13 cnrs laga université paris 13': 'not found',
#  'umr 8596 universite': 'not found',
#  'université louis pasteur': 'not found',
#  'université joseph fourier': 'not found',
#  'université paris diderot bât': 'not found',
#  'université paris diderot christophe': 'not found',
#  'étudiante de doctorat à l école': 'not found',
#  'universitaire st jean d angély': 'not found',
#  'a violência da pesquisa na ponta da caneta mahalia lassibille université de paris 8 -vincennes saint denis violência da pesquisa na ponta da caneta mahalia lassibille université': 'not found',
#  'institut national d études démographiques': 'not found',
#  'université de paris 13': 'not found',
#  'institute for the science of human history 07745': 'not found',
#  'institut de recherche interdisciplinaire de grenoblecea-grenoble17': 'not found',
#  'école nationale supérieure d architecture paris la villette et membre du laboratoire espaces travail': 'not found',
#  'université catholique de lille et chercheur associé à l ifg-lab': 'not found',
#  'radbouduniversiteit': 'not found',
#  'institut d asie orientale': 'not found',
#  'école de formation professionnelle des barreaux du ressort de la cour d appel de paris': 'not found',
#  'agence de mutualisation des universités': 'https://ror.org/04wb96h67',
#  'institut national universitaire champollion': 'not found',
#  'université pascal paoli': 'not found',
#  'maître de conférences en psychopathologie clinique utrpp -ea 3413 université': 'not found',
#  'retour à l école': 'not found',
#  'université nice sophia antipolis': 'not found',
#  'universitaire des saints-pères': 'not found',
#  'edhec business school': 'https://ror.org/05q7a8a02',
#  'institut de recherche en informatique de toulouse': 'https://ror.org/01rx4qw44',
#  'ascencia business school': 'not found',
#  'centre de recherches sociologiques et politiques de paris frédérique leblanc université': 'not found',
#  'doctorante à l université': 'not found',
#  'martin lefebvre est professeur d études cinématographiques et titulaire de la chaire de recherche en études cinématographiques de l université': 'not found',
#  'institut de recherche juridique sur l entreprise et les relations professionnelles': 'https://ror.org/0570kre10',
#  '21 rue de l école': 'not found',
#  '21 allée de l université92023': 'not found',
#  'école nationale supérieure d architecture de la ville et des territoires à marne-la-vallée': 'not found',
#  'laboratoire analyse géométrie et applications institut galilée université': 'not found',
#  'institut mines-télécom business school': 'https://ror.org/00nsf1h45',
#  'école nationale supérieure d électronique': 'not found',
#  'institut de recherche en horticulture et semences': 'https://ror.org/02xq0x374',
#  'université paris lumières': 'https://ror.org/03b4d6f26',
#  'universitaire de saint-martin-d hères adresse postale': 'not found',
#  'university in france': 'not found',
#  'maître de conférences en psychologie université': 'not found',
#  'université paris-8 et idhes': 'not found',
#  'ladyss université': 'not found',
#  'laboratoire d informatique de l université': 'not found',
#  'et université': 'not found',
#  'institut national des jeunes sourds de metz': 'not found',
#  'universitaires de paris sorbonne': 'not found',
#  'institut des politiques publiques': 'not found',
#  'institut d optique d aquitainerue françois mitterrand33400 talencefrance': 'not found',
#  'institut de prospective economique du monde méditerranéen': 'not found',
#  'university paris-diderot 5 rue thomas mann 75013 paris france': 'not found',
#  'university of paris university of paris': 'not found',
#  'équipe archéologie du proche-orient hellénistique et romain institut': 'not found',
#  'at the université': 'not found',
#  'cepeduniversité': 'not found',
#  'jiyoung kim est doctorante en sociologie à l université': 'not found',
#  'université bretagne loire': 'not found',
#  'editore presses universitaires de paris nanterre editore presses universitaires': 'not found',
#  'university paris 8 saint-denis france': 'not found',
#  'institut bergonié': 'https://ror.org/02yw1f353',
#  'institut supérieur de gestion paris': 'not found',
#  'financé par l université': 'not found',
#  'elle exerce actuellement la fonction d ingénieure de recherches au centre céreq-eso-université': 'not found',
#  'université nantes angers le mans': 'https://ror.org/0406t3m57',
#  'ap-hp hôpital universitaire': 'not found',
#  'institut mediterranéen des sciences de l information et de la communication': 'https://ror.org/00c62kq26',
#  'france professeure de psychologie laboratoire de psychopathologie et neuropsychologie université': 'not found',
#  'management ipag business school': 'not found',
#  'maîtresse de conférences en sciences de l information et de la communication à l université': 'not found',
#  'universitat pompey fabra': 'not found',
#  'centre de recherches de l institut de démographie de l université': 'not found',
#  'institut agro rennes angers': 'https://ror.org/01s3fs709',
#  'université jean moulin lyon 3': 'not found',
#  'institutions pénales': 'https://ror.org/01qm1tk92',
#  '1 professeur émérite de démographie de l université': 'not found',
#  'institute of high energy physics': 'not found',
#  'institut universitaire européen': 'https://ror.org/04pfr1b11',
#  'university of paris 1 panthéon-sorbonne': 'not found',
#  'universitaire du madrillet': 'not found',
#  'ihtp -cnrs -université': 'not found',
#  'institut de recherche sur l éducation': 'https://ror.org/019qdtz78',
#  'universität paris-8': 'not found',
#  'institut de pharmacologie moléculaire et cellulaire': 'https://ror.org/05k4ema52',
#  'école nationale supérieure d architecture de versailles': 'not found',
#  'university of molise': 'not found',
#  'universitaire de jacob-bellecombette': 'not found',
#  'france department of geography laboratories mosaïques-lavue and ceias university': 'not found',
#  'observatoire aquitain des sciences de l univers': 'https://ror.org/03qma7a12',
#  'institut de biologie du développement de marseille': 'not found',
#  'institut de recherche interdisciplinaire de grenoble': 'https://ror.org/00byxdz40',
#  'université paris ouest nanterre la défense': 'https://ror.org/013bkhk48',
#  'université paris université paris': 'not found',
#  'professeur de sociologie de l art université': 'not found',
#  'institutionnelles et juridiques': 'https://ror.org/016btc076',
#  'maître de conférences au département cinéma de l université': 'not found',
#  'marie pruvost-delaspre est maîtresse de conférences au département cinéma de l université': 'not found',
#  'institut d urbanisme de paris': 'not found',
#  'universités et établissements': 'https://ror.org/04wb96h67',
#  'institut de l élevage': 'https://ror.org/01csjkt09',
#  'école nationale supérieure d arts et métiers': 'not found',
#  'institut pour l avancée des biosciencescentre de recherche uga': 'not found',
#  'université rené descartes 45 rue des saints pères 75270 paris cedex 06': 'not found',
#  'université de toulouse 2 le mirail où elle dirige le département art': 'not found',
#  'institut de recherche mathématique avancée': 'https://ror.org/02hwgty18',
#  'university of paris 8 led': 'not found',
#  'institut d études politiques': 'not found',
#  'a école': 'not found',
#  'centre de documentation de l institut des civilisations du collège': 'not found',
#  'lri cnrs université': 'not found',
#  'institut lumière matière': 'https://ror.org/0323bey33',
#  'françois chaubet est professeur d histoire contemporaine à l université': 'not found',
#  'universitaire saint jean d angely bâtiment sja 3 24 avenue des diables bleus': 'not found',
#  'mestre de conferência em ciências da linguagem na universidade paris 8 e orientadora adjunta da estrutura doutora em história mestre de conferência em ciências da linguagem na universidade': 'not found',
#  'lille 3 domaine universitaire': 'not found',
#  'céline frigau manning est maître de conférences en études théâtrales et italiennes à l université paris 8 et membre de l institut universitaire': 'not found',
#  '75231 paris cedex 05 l sorbonne université': 'not found',
#  'aix marseille université29': 'not found',
#  'université de paris ouest nanterre professeur invitée à el colegio de méxico': 'not found',
#  'institut national de la recherche agronomique': 'not found',
#  'publié par edinburgh university': 'not found',
#  'institut cellule souche et cerveau': 'https://ror.org/03m0zs870',
#  'université paris- viii vincennes-saint-denis': 'https://ror.org/04wez5e68',
#  'maxime cervulle est maître de conférences en science de l information et de la communication à l université': 'not found',
#  'cnrs-université': 'not found',
#  'est maître de conférences à l université': 'not found',
#  'idhes école': 'not found',
#  'université paris i panthéon sorbonne université paris i panthéon sorbonne': 'not found',
#  'institut national polytechnique de grenoble': 'not found',
#  'institut fresnel': 'https://ror.org/03br1wy20',
#  'institut national du sport': 'https://ror.org/03jczk481',
#  'université d aix-marseille centre schuman': 'not found',
#  'institut de recherche dupuy de lôme': 'https://ror.org/03011gg73',
#  'institut de recherche technologique': 'https://ror.org/03011gg73',
#  'institut de recherche et d histoire des textes': 'not found',
#  'sfl umr 7023 cnrs university': 'not found',
#  'université paris 13 ufr lsh 99 avenue jean baptiste clément 3971': 'not found',
#  'du rapport de l école': 'not found',
#  'université pierre mendès france': 'not found',
#  'université concordia': 'not found',
#  'docteur de l institut': 'not found',
#  'école supérieure d art d avignon': 'not found',
#  '1 laboratoire paragraphe université': 'not found',
#  'centre de recherches sociologiques et politiques de paris institut': 'not found',
#  'institut des hautes études de l amérique latine': 'not found',
#  'institut curie': 'https://ror.org/04t0gwh46',
#  'universitaire des saints-pères 45 rue des saints-pères 75270 paris cedex 06': 'not found',
#  'university paris 13': 'not found',
#  'université du mans': 'not found',
#  'led université': 'not found',
#  'avenue paul delouvrier cs 20749 montigny 78066 saint quentin en yvelines parc universitaire': 'not found',
#  'école': 'https://ror.org/00fmnpw63',
#  'université paris ouest nanterre la défense bâtiment t 200 avenue de la république 92001 nanterre cedex': 'not found',
#  'cíntia tosta université': 'not found',
#  'university of louvain': 'not found',
#  'ie university': 'not found',
#  'école supérieure d ingénierie léonard de vinci': 'not found',
#  'faculté de médecineuniversité': 'not found',
#  'institut des langues et cultures d europe': 'not found',
#  'école primaire ruvoletto': 'not found',
#  'institut national de l audiovisuel': 'https://ror.org/02zwkwz55',
#  'universités université de toulon laboratoire i3m associé laboratoire paragraphe de paris 8 consultant grico professeur emérite des universités laboratoire i3m associé laboratoire paragraphe de paris 8 consultant grico université de toulon': 'not found',
#  'university institute': 'https://ror.org/013pnfx92',
#  'école nationale supérieure de formation de l enseignement agricole de toulouse-auzeville': 'not found',
#  'allée de l université': 'not found',
#  'institutions et dynamiques historiques de l économie et de la société': 'https://ror.org/03p76m698',
#  'doctorante à l école universitaire': 'not found',
#  'institut de l humanitaire': 'not found',
#  'institut d études politiques de toulouse': 'not found',
#  'maison des universités': 'not found',
#  'institut national des sciences appliquées hauts-de-france': 'https://ror.org/041rsh762',
#  'linx revue des linguistes de l université': 'not found',
#  'institut galilée université paris 13': 'not found',
#  'galerie colbertbureaux 527-528institut': 'not found',
#  'école d histoire de la sorbonne': 'not found',
#  'laboratoire est inscrite en deuxième année de thèse à l université': 'not found',
#  'università di corsica': 'not found',
#  'affiliée à l institut': 'not found',
#  'universitaire des saints pères45 rue des saints-peres75270 paris cedex 06': 'not found',
#  'institut d administration économique et sociale': 'not found',
#  'auriane guilbaud est maître de conférences en science politique à l université': 'not found',
#  'université paris ouest nanterre': 'https://ror.org/013bkhk48',
#  'sabine effosse is professor of contemporary history at paris nanterre university': 'not found',
#  'france ulrike lune riboni université': 'not found',
#  'institut national de recherches archéologiques préventives': 'https://ror.org/04andmq85',
#  'université de franche comté': 'not found',
#  'université de paris cergy': 'not found',
#  'yves sintomer is professor of political science at paris 8 university': 'not found',
#  'université de nantes rue christian pauc': 'not found',
#  'université paris ouest nanterre la défense umr 7218 lavue': 'not found',
#  'institut d études politiques de bordeaux': 'not found',
#  'institute for the science of human history': 'not found',
#  'université4 place jussieu 75005 pariscouloir 46-45': 'not found',
#  'école nationale d ingénieurs de brest': 'not found',
#  'ionian university': 'not found',
#  '685 avenue de l université': 'not found',
#  'france umr 7041 arscan -21 allée de l université': 'not found',
#  'universitaire pont de bois': 'not found',
#  'institut de la mer de villefranche': 'https://ror.org/05jpad840',
#  'umr cnrs 8533 université': 'not found',
#  'école universitaire de recherche translitteræ': 'not found',
#  'universitaire de tours2 boulevard tonnellé 37044 tours cedex 9': 'not found',
#  'université autonome de madrid': 'not found',
#  'laboratoire inter-universitaire': 'not found',
#  'rue des universités': 'not found',
#  'pauline delage travaille à présent à l université': 'not found',
#  'institut national de prévention et d éducation pour la santé': 'not found',
#  'école centrale de nantes': 'https://ror.org/03nh7d505',
#  'université bp 12 76801 saint-étienne-du-rouvray': 'not found',
#  'institut mutualiste de montsouris': 'not found',
#  'institut michel villey pour la culture juridique et la philosophie du droit': 'https://ror.org/04jkwt097',
#  'professeuse en psychologie de l orientation à l université': 'not found',
#  'universite paris-4-sorbonne 1 rue victor cousin 75230 paris cedex 05': 'not found',
#  'université lumière lyon25': 'not found',
#  'universitaire lorrain d histoire': 'not found',
#  'professeure de psychologie université': 'not found',
#  'de l école': 'not found',
#  'institut formation education physique et sportive angers': 'not found',
#  'professeur des universités': 'not found',
#  'university of notre dame notre dame': 'not found',
#  'umr8155 collège': 'not found',
#  'université de campinas': 'not found',
#  'universitaire de la francophonie': 'not found',
#  'paris université de lausanne and sorbonne université': 'not found',
#  'universitaire histoire cultures italie europe': 'https://ror.org/00y523k32',
#  'institut convergences migrations delphine': 'not found',
#  'institut des sciences et pratiques d éducation et de formation': 'not found',
#  'hesam université': 'https://ror.org/042949r55',
#  'university of paris 8 vincennes-saint denis': 'not found',
#  'université de brest': 'https://ror.org/0372th171',
#  'presses universitaires de france presses universitaires': 'not found',
#  'institutions': 'not found',
#  'toulouse school': 'https://ror.org/00ff5f522',
#  'école nationale supérieure d architecture de saint-étienne': 'not found',
#  'darmangeat est enseignant à l université': 'not found',
#  'fr sfl -cnrs université': 'not found',
#  'sorbonne universite': 'https://ror.org/044feat76',
#  'is a geographer at the lavue laboratory and a research and teaching assistant at aix-marseille university': 'not found',
#  'institut de recherche en energie electrique de nantes atlantique ea4642': 'not found',
#  'université paris-sud 91405 orsay cedex': 'not found',
#  'school of management': 'https://ror.org/0207fe012',
#  'transcrit université': 'not found',
#  'université paris diderot ufr ghes case 7001 75205 paris cedex 13': 'not found',
#  'geste et corporéité à l université': 'not found',
#  'université paris 13 sorbonne paris cité laga': 'not found',
#  'maison de la recherche université': 'not found',
#  'université paul sabatier': 'https://ror.org/02v6kpv12',
#  'maison interuniversitaire': 'https://ror.org/02jm89840',
#  'institut de génétique': 'https://ror.org/02jm89840',
#  'école des minessite de clavières': 'not found',
#  'university paris 8 2 rue de la liberté 93526 saint-denis france': 'not found',
#  'et membre du centre de recherche sur l action politique de l université': 'not found',
#  'université vincennes': 'not found',
#  'institut de mathématiques et de modélisation de montpellier': 'not found',
#  'université d aix-marseille5 avenue pasteur b': 'not found',
#  'route de mendeuniversité': 'not found',
#  'institut d études européennes': 'not found',
#  'paris diderot university': 'not found',
#  'université paris 10': 'not found',
#  'professeur de musicologie à l université': 'not found',
#  'université lumière lyon 2': 'https://ror.org/03rth4p18',
#  'institut national d enseignement supérieur pour l agriculture': 'not found',
#  'université paris-8 2': 'not found',
#  'toulouse business school': 'https://ror.org/0349y2q65',
#  'professeur emérite des universités université de toulon laboratoire i3m associé laboratoire paragraphe de paris 8 consultant grico professeur emérite des universités laboratoire i3m associé laboratoire paragraphe de paris 8 consultant grico université': 'not found',
#  'maîtresse de conférences en sciences de l éducation à l université': 'not found',
#  'institut des sciences moléculaires': 'not found',
#  'french university': 'not found',
#  'université de technologie de belfort-montbeliard': 'https://ror.org/05bn3m307',
#  'institut de recherche en droit international et européen de la sorbonne': 'not found',
#  'institut national de l environnement industriel et des risques': 'https://ror.org/034yrjf77',
#  'institut agronomique méditerranéen de montpellier': 'https://ror.org/0005r2j17',
#  'applica-tions umr 7539 institut': 'not found',
#  'institute paris': 'https://ror.org/02f1mqt91',
#  'où il a créé en 2009 un master en médiation de l art contemporain et où il gère une galerie universitaire': 'not found',
#  '69364 lyon cedex 07université': 'not found',
#  'université paris-sud rue des adèles 91405 orsay cedex': 'not found',
#  'école des hautes études en démographie': 'not found',
#  'institut de recherche interdisciplinaire sur les enjeux sociaux': 'https://ror.org/03xg8m734',
#  'institut polytechnique de grenoble': 'https://ror.org/05sbt2524',
#  'en cotutelle avec l université': 'not found',
#  'università di corsica pasquale paoli': 'not found',
#  'école nationale d administration': 'not found',
#  'institut technologique forêt cellulose bois-construction ameublement': 'https://ror.org/02q8h2f47',
#  'université lyon 2 mh14 avenue berthelot69365 lyon cedex 07': 'not found',
#  'école nationale supérieure d architecture de grenoble': 'not found',
#  'professeur à l université': 'not found',
#  'sylviane pagès est maître de conférences au département danse de l université': 'not found',
#  'laga department of mathematics university': 'not found',
#  'from elementary to university': 'not found',
#  'institut national de la santé et de la recherche médicale': 'https://ror.org/02vjkv261',
#  'université de nice sophia-antipolis 06103 nice université de toulon 83957 la garde': 'not found',
#  'professeur émérite d histoire contemporaine à l université': 'not found',
#  'institut d histoire du temps présent': 'not found',
#  'universite': 'https://ror.org/03z6jp965',
#  'universitaire de recherche en education de lille': 'not found',
#  'university paris nanterre france': 'not found',
#  'université paris 1 panthéon-sorbonne intitulée': 'not found',
#  'pôle univ': 'not found',
#  'laboratoire analyse géométrie et applications umr 7539 cnrs université': 'not found',
#  'professeur à l institut': 'not found',
#  'de l université de prishtina et de l institut': 'not found',
#  'institut agro agrocampus ouest': 'not found',
#  'université de paris-est': 'not found',
#  'université paris 13 france': 'not found',
#  'institut montpelliérain alexander grothendieck': 'https://ror.org/044kxby82',
#  'universite victor segalen 146': 'not found',
#  'maître de conférences au département de science politique à l université': 'not found',
#  'professeur de sciences économiques université': 'not found',
#  'maitresse de conférences en didactique des langues à l université': 'not found',
#  'université sciences et technologies': 'not found',
#  'école doctorale informatique': 'not found',
#  'institut français d urbanisme': 'not found',
#  'école de psychologues praticiens de paris': 'not found',
#  'cerosuniversité': 'not found',
#  'institut de recherche sur les transports': 'not found',
#  'école doctorale de sciences sociales -université paris 8 courriel école doctorale de sciences sociales université': 'not found',
#  'université 75007 paris': 'not found',
#  'institut du monde anglophone université sorbonne nouvelle': 'not found',
#  'labex dynamite université': 'not found',
#  'université paris 13 -sorbonne paris cité 53 rue vivienne 75002 paris': 'not found',
#  'equipe anthropologie des techniques des espaces et des territoires au plioc ene et au pl eistoc ene mae 21 all ee de l universit': 'not found',
#  'cy lt2dcy cergy paris universitésite': 'not found',
#  'université de paris-nanterre': 'not found',
#  'université de naples frédéric ii': 'not found',
#  'de conférences en sociologie de la santé université': 'not found',
#  'university paris 8': 'not found',
#  'univers et particules de montpellier': 'https://ror.org/00nrbzg90',
#  'esg management school': 'https://ror.org/01y414495',
#  'directrice de l idhes-nanterre cnrs et membre de l institut universitaire': 'not found',
#  'école de psychologues praticiens de l institut catholique de paris': 'not found',
#  'camille masclet est doctorante en sociologie politique à l université': 'not found',
#  'school of economics 48 bd jourdan 75014 paris france': 'not found',
#  'institut rhônalpin des systèmes complexes': 'https://ror.org/00prvqp73',
#  'école urbaine': 'not found',
#  'université de nîmes': 'not found',
#  'ethics ea 7446 université': 'not found',
#  'institut de recherches sur l evolution de la nation et de l etat': 'https://ror.org/04gmrh438',
#  'université5 avenue pasteur13100 aix-en-provence': 'not found',
#  'institut de mathématiques de marseille': 'https://ror.org/042h2y225',
#  'universitaires de nanterre': 'not found',
#  'circeft-escol université': 'not found',
#  'docteur en géopolitique de l institut français de géopolitique de l université': 'not found',
#  'institut d histoire moderne et contemporaine': 'not found',
#  'universitaire laval changé': 'not found',
#  'university of paris-saclay paris': 'not found',
#  'institutions et dynamiques historiques de l économie': 'https://ror.org/03p76m698',
#  'universidade paris 8 e orientadora adjunta da estrutura doutora em história mestre de conferência em ciências da linguagem na universidade paris 8 e orientadora adjunta da estrutura': 'not found',
#  'laga cnrs université': 'not found',
#  'institut du développement durable et des relations internationales': 'https://ror.org/02j05s068',
#  'institut national supérieur des sciences agronomiques': 'https://ror.org/03zek0r74',
#  'école de droit de sciences po': 'not found',
#  'école des arts de la sorbonne': 'not found',
#  'universitaire de brest': 'https://ror.org/03evbwn87',
#  'université de fribourg': 'not found',
#  'susan ball is senior lecturer in contemporary british civilisation and member of the research group transcrit at the university': 'not found',
#  'institut de recherche pour le développement': 'https://ror.org/05q3vnk25',
#  'laboratoire univers': 'https://ror.org/05q3vnk25',
#  'cnrs-univ': 'not found',
#  'universitaires de france presses éditions presses universitaires france presses': 'not found',
#  'institut français de pondichéry': 'not found',
#  'institut d archéologie de l académie nationale des sciences d ukraine': 'not found',
#  'université 64000 pau': 'not found',
#  'lille university': 'https://ror.org/02hkbys70',
#  'docteure en géographie prag à l université': 'not found',
#  'paris i university': 'not found',
#  'enseigne au lycée grandmont à tours et à l université': 'not found',
#  'professeure d histoire moderne à l université': 'not found',
#  'université 92000 nanterre france': 'not found',
#  'école supérieure de commerce': 'https://ror.org/000axn811',
#  'umr 7218 université': 'not found',
#  'université jean moulin lyon 3 6 cours albert thomas bp 8242 69355 lyon cedex 08': 'not found',
#  ...}

# %%
t_etab2 = t_etab1.loc[~t_etab1.id_rors.isna()]
t_etab3 = t_etab1.loc[t_etab1.id_rors.isna()]
t_etab2["rors"] = "https://ror.org/" + t_etab2.id_rors.astype(str)
t_etab3["rors"] = t_etab3.etab.map(dict_ror2.get)
t_etab3.loc[t_etab3.rors!="not found"].drop_duplicates("cleaned_etab")
# Out:
# /tmp/ipykernel_11041/4135308318.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_etab2["rors"] = "https://ror.org/" + t_etab2.id_rors.astype(str)
# /tmp/ipykernel_11041/4135308318.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   t_etab3["rors"] = t_etab3.etab.map(dict_ror2.get)
#                               id rank_id  \
# 0                halhal-03933378       0
# 2                halhal-03933378       7
# 16               halhal-04579883      12
# 17               halhal-04579883      12
# 22               nnt2006troy0017      15
# ...                          ...     ...
# 115447  doi10.3917/rfse.013.0241   54956
# 117277           halhal-04672512   55846
# 117583  doi10.3917/arch.221.0153   56010
# 118053           halhal-04484125   56250
# 118175   doi10.4000/pallas.19740   56300
#
#                                                      etab  \
# 0       institut national de recherches archéologiques...
# 2                    université paris 1 panthéon-sorbonne
# 16                                             université
# 17                               aix marseille université
# 22               institut supérieur de mécanique de paris
# ...                                                   ...
# 115447         université paris ouest nanterre-la défense
# 117277      institut national de recherche et de sécurité
# 117583                       école normale supérieure-psl
# 118053                                   institut fresnel
# 118175               université paris 1-panthéon sorbonne
#
#                                              cleaned_etab norm_name id_rors  \
# 0       institut national recherches archéologiques pr...      None    None
# 2                    université paris 1 panthéon-sorbonne      None    None
# 16                                             université      None    None
# 17                               aix marseille université      None    None
# 22                     institut supérieur mécanique paris      None    None
# ...                                                   ...       ...     ...
# 115447         université paris ouest nanterre-la défense      None    None
# 117277            institut national recherche et sécurité      None    None
# 117583                       école normale supérieure-psl      None    None
# 118053                                   institut fresnel      None    None
# 118175               université paris 1-panthéon sorbonne      None    None
#
#                              rors
# 0       https://ror.org/04andmq85
# 2       https://ror.org/002t25c44
# 16      https://ror.org/03z6jp965
# 17      https://ror.org/035xkbk20
# 22      https://ror.org/04dtfqt68
# ...                           ...
# 115447  https://ror.org/013bkhk48
# 117277  https://ror.org/01dg85j68
# 117583  https://ror.org/05a0dhs15
# 118053  https://ror.org/03br1wy20
# 118175  https://ror.org/002t25c44
#
# [356 rows x 7 columns]

# %%
df_allrors = pd.concat([t_etab2[["id","rank_id","rors"]], t_etab3[["id","rank_id","rors"]]])

df_adfr["rors"] = df_adfr.rank_id.map(dict(zip(df_allrors.rank_id, df_allrors.rors)))
df_umr = df_adfr.loc[df_adfr.name_umr!=""]
df_umr["umr"] = df_umr.name_umr.str.split("|")
df_umr1 = df_umr[["id","rank_id","umr"]].explode("umr").reset_index().drop(columns=["index"])
df_umr1["umr_id"] = df_umr1.index.astype(str)
df_umr1
# Out:
# /tmp/ipykernel_11041/477849833.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_umr["umr"] = df_umr.name_umr.str.split("|")
#                     id rank_id      umr umr_id
# 0      halhal-03933378       1  umr7324      0
# 1      halhal-03933378       1  umr6173      1
# 2      halhal-03933378       7  umr7041      2
# 3      halhal-03895949       8  umr7041      3
# 4      halhal-01789653       9   ea1572      4
# ...                ...     ...      ...    ...
# 34903  halhal-04366816   56310    ea827  34903
# 34904  halhal-02120667   56313  umr7041  34904
# 34905  halhal-02120667   56314  umr5600  34905
# 34906  halhal-02120667   56315  umr7266  34906
# 34907  halhal-01964707   56316  umr7023  34907
#
# [34908 rows x 4 columns]

# %%
list_umr = list(set([x for x in df_umr1.umr]))
print(len(list_umr))
dict_ror3 = {}
for m, umr in tqdm.tqdm(enumerate(list_umr), total = len(list_umr)):
    label_umr = umr.replace("umr","umr ").replace("ea","ea ").replace("ums", "ums ")
    
    response = requests.get(ROR_API_ENDPOINT + '?' + f'query="{label_umr}"' + "&filter=country.country_code:fr").json()
    if response["number_of_results"] > 1 :
        for n, x in enumerate(response["items"]):
            if 'education' in x["types"] :
                datas = response["items"][n]
                rors = datas["id"]
    elif response["number_of_results"] == 1 :
        datas = response["items"][0]
        rors = datas["id"]
    else:
         rors = "not found"
    dict_ror3[umr] = rors
    #print(cleaned_etab, rors)
# Out:
# 1120
# 100%|██████████| 1120/1120 [02:27<00:00,  7.60it/s]

# %%
file_path = BUCKET_OUT + "/" + "/Data_bso/referentiels/fr-esr-repertoire-national-structures-recherche-historique-annuel.csv"
with fs.open(file_path) as csvin:
    umr_histo = pd.read_csv(csvin, sep =";")
    

file_path = BUCKET_OUT + "/" + "/Data_bso/referentiels/fr-esr-structures-recherche-publiques-actives.csv"
with fs.open(file_path) as csvin:
    umr = pd.read_csv(csvin, sep =";")
    
umr1 = umr.loc[~umr.label_numero.isna()]
umr1.loc[umr1.label_numero.str.contains("EA 4178")]
umr_histo1 = umr_histo.loc[~umr_histo["Label numéro"].isna()]
umr_histo1.loc[(umr_histo1["Label numéro"].str.contains("UMR 8608"))&(umr_histo1["Année"]==umr_histo1["Année"].max())].iloc[0]
# Out:
# Année                                                                                              2017
# Numéro national de structure                                                                 199812935Y
# Label numéro                                                                          UMR 8608,UMR 8608
# Tutelles                                              Centre national de la recherche scientifique,U...
# Sigles des tutelles                                                                                CNRS
# SIRET des tutelles                                                                                  NaN
# UAI des tutelles                                                                      0753639Y,0911101C
# Code de type de tutelle                                                                       EPST,UNIV
# Type de tutelle                                       Établissement public scientifique et technolog...
# Code de nature de tutelle                                                                           6,6
# Nature de tutelle                                           Établissement tutelle,Établissement tutelle
# Numéro de structure parent                                                                          NaN
# Numéro de structure enfant                                                                          NaN
# Prénom du responsable                                                                            Faiçal
# Nom du responsable                                                                               AZAIEZ
# Titre du responsable                                                                          Directeur
# Email du responsable                                                                                NaN
# Code domaine scientifique                                                                           NaN
# Domaine scientifique                                                                                NaN
# Code panel ERC                                                                                      NaN
# Panel ERC                                                                                           NaN
# Code thème de recherche                                                                             NaN
# Thème de recherche                                                                                  NaN
# Lien répertoire national de structure de recherche    https://data.enseignementsup-recherche.gouv.fr...
# Lien structures de recherche actives                  https://data.enseignementsup-recherche.gouv.fr...
# Name: 55826, dtype: object

# %%
file_path = BUCKET_OUT + "/" + "/Data_bso/referentiels/fr-esr-repertoire-national-structures-recherche.csv"
with fs.open(file_path) as csvin:
    rnsr = pd.read_csv(csvin, sep =";")

rnsr.loc[rnsr.numero_national_de_structure=="202023524M"]
# Out:
#       numero_national_de_structure  \
# 11805                   202023524M
#
#                                                  libelle   sigle    etat  \
# 11805  Laboratoire de physique des 2 infinis – Irène ...  IJCLab  Active
#
#        annee_de_creation  annee_de_fermeture type_de_structure  \
# 11805             2020.0                 NaN       Unité mixte
#
#        code_de_type_de_structure  code_de_niveau_de_structure  \
# 11805                         22                            2
#
#       numero_de_structure_successeur code_de_type_de_succession  \
# 11805                            NaN                        NaN
#
#       type_de_succession annee_de_succession
# 11805                NaN                 NaN

# %%
print(len([x for x in dict_ror3 if dict_ror3[x]=="not found"]))
# Out:
# 737

# %%
for umr in dict_ror3:
    if dict_ror3[umr] == "not found":
        print("######", umr)
        label_umr = umr.replace("umr_","umr").replace("umr","umr ").replace("ea","ea ").replace("ums", "ums ").replace("  ", " ")
        try:
            libelle = umr1.libelle.loc[umr1.label_numero.str.lower().str.contains(label_umr)].iloc[0]
            commune = umr1.commune.loc[umr1.label_numero.str.lower().str.contains(label_umr)].iloc[0]
        except:
            libelle = "unknown"
            commune = "unknown"
        if libelle != "unknown":
            libelle= libelle.replace("&","and")
            print(libelle)
            response = requests.get(ROR_API_ENDPOINT + '?' + f'query="{libelle.lower()}"' + "&filter=country.country_code:fr").json()
            if response["number_of_results"] > 1 :
                for n, x in enumerate(response["items"]):
                    if 'education' in x["types"] :
                        datas = response["items"][n]
                        rors = datas["id"]
                        dict_ror3[umr] = rors
            elif response["number_of_results"] == 1 :
                datas = response["items"][0]
                rors = datas["id"]
                dict_ror3[umr] = rors
            else:
                 rors = "not found"
# Out:
# ###### ea4178
# CENTRE PLURIDISCIPLINAIRE TEXTES ET CULTURES - UR 4178
# ###### umr8608
# ###### umr8109
# ###### ea7464
# Architecture Territoire Environnement Normandie
# ###### umr7249
# Institut Fresnel Marseille
# ###### umr9190
# MARine Biodiversity, Exploitation and Conservation
# ###### eau33000
# ###### umr154
# ###### umr5313
# Laboratoire d'Economie Appliquée de Grenoble
# ###### umr_8225
# ###### ea2445
# ###### umr1326
# Laboratoire Interdisciplinaire Sciences, Innovations, Sociétés
# ###### umr5805
# Environnements et paléoenvironnements océaniques et continentaux
# ###### ea4009
# ###### umr1397
# LABORATOIRE DE RECHERCHE EN CARDIOVASCULAIRE, METABOLISME, DIABETOLOGIE ET NUTRITION
# ###### ea7425
# ###### umr6607
# Laboratoire de Thermique et Énergie de Nantes
# ###### umr0985
# Dynamique et durabilité des écosystèmes : de la source à l’océan
# ###### ea3897
# RECHERCHES ET ETUDES SUR LES CHOIX INDUSTRIELS, TECHNOLOGIQUES ET SCIENTIFIQUES
# ###### umr_7164
# ###### umr6204
# ###### ea3214
# ###### ea7390
# ###### ea4306
# ###### umr8179
# ###### umr5605
# ###### eau34300
# ###### umr9220
# Ecologie marine tropicale dans les Océans Pacifique et Indien
# ###### umr7064
# Centre méditerranée de sociologie, de science politique et d'histoire
# ###### ea4333
# THEMIS UNIVERSITE DU MANS
# ###### umr6574
# ###### umr8044
# Centre d'étude des mouvements sociaux
# ###### umr8554
# Laboratoire de sciences cognitives et psycholinguistique
# ###### ea3263
# LABORATOIRE MANCEAU DE MATHEMATIQUES
# ###### umr7183
# ###### ea608
# GROUPE DE RECHERCHE SUR LES ENJEUX DE LA COMMUNICATION
# ###### umr1459
# ###### umr5292
# Centre de Recherche en Neurosciences de Lyon
# ###### ea4461
# Ecole de droit de Sciences Po
# ###### ums104
# ###### ea375
# ###### ea4512
# ###### ea4601
# PATRIMOINE LITTÉRATURE HISTOIRE
# ###### umr3495
# Modèles et simulations pour l'Architecture et le Patrimoine
# ###### umr1202
# Biodiversité, Gènes et Communautés
# ###### ea4385
# LABORATOIRE D'ÉTUDES ROMANES
# ###### umr5602
# GEOGRAPHIE DE L'ENVIRONNEMENT
# ###### umr7013
# UMR 7013 Institut Denis Poisson
# ###### umr7031
# Laboratoire de mécanique et d'acoustique
# ###### umr7360
# Laboratoire Interdisciplinaire des Environnements Continentaux
# ###### ea4314
# GROUPE DE RECHERCHE IDENTITÉS ET CULTURES - UR 4314
# ###### ea1441
# ###### umr_7586
# ###### ea3804
# Centre de REcherche en STIC
# ###### ea4509
# SENS, TEXTE, INFORMATIQUE, HISTOIRE
# ###### umr7353
# ###### ea3159
# ###### ea4429
# ###### ea7339
# DISPOSITIFS D'INFORMATION ET DE COMMUNICATION À L'ÈRE NUMÉRIQUE PARIS ILE DE FRANCE
# ###### ea3811
# HELLENISATION ET ROMANISATION DANS LE MONDE ANTIQUE : IDENTITES ET PHENOMENES INTERCULTURELS
# ###### ums3665
# ###### umr8178
# ###### ea7465
# Groupe de Recherche sur l'Invention et l'Evolution des Formes
# ###### umr6633
# ###### ea1587
# ###### umr8246
# ###### umr5025
# ###### ea4256
# ###### umr91
# MARine Biodiversity, Exploitation and Conservation
# ###### umr6598
# LABORATOIRE DE RECHERCHE EN HYDRODYNAMIQUE, ENERGÉTIQUE ET ENVIRONNEMENT ATMOSPHÉRIQUE
# ###### ea4129
# PARCOURS SANTE SYSTEMIQUE
# 545

# %%
print(len([x for x in dict_ror3 if dict_ror3[x]!="not found"]))
df_umr1["rors"] = df_umr1.umr.map(dict_ror3.get)
df_umr2 = df_umr1.loc[df_umr1.rors!="not found"]
df_adfr["umr_ror"] = df_adfr.rank_id.map(dict(zip(df_umr2.rank_id, df_umr2.rors)).get)
pd.concat([df_adfr[["id","rank_id","rors"]], df_umr2[["id","rank_id","rors"]]]).drop_duplicates()
# Out:
# 575
#                     id rank_id                       rors
# 0      halhal-03933378       0  https://ror.org/04andmq85
# 1      halhal-03933378       1  https://ror.org/02wwzvj46
# 2      halhal-03933378       2                        NaN
# 3      halhal-03933378       3                        NaN
# 4      halhal-03933378       4                        NaN
# ...                ...     ...                        ...
# 34903  halhal-04366816   56310  https://ror.org/01bxfc994
# 34904  halhal-02120667   56313  https://ror.org/00wx1mx58
# 34905  halhal-02120667   56314  https://ror.org/0256r1e04
# 34906  halhal-02120667   56315  https://ror.org/00r8amq78
# 34907  halhal-01964707   56316  https://ror.org/00nrven85
#
# [76450 rows x 3 columns]

# %%
#récupéré sur Le Chat via la demande suivante : how can i detect unstructured address in text

nlp = spacy.load("fr_core_news_md")

for index, row in df_frwithoutumr.head(20).iterrows():
    print("######", row.address)
    doc = nlp(row.address)
    for ent in doc.ents:
        #print(ent.text)
        ent.
        if ent.label_ == "ORG" or ent.label_ == "LOC":
            print(ent.text)

# %% [markdown]
# # Les institutions non françaises

# %%
df_nofr = df_ad.loc[~(df_ad.address.str.lower().str.contains("france|paris"))].reset_index().drop(columns=["index"])
df_nofr#.loc[~df_nofr.affiliation.isna()]

# %%
for

# %%
key ='École doctorale Pratiques et théories du sens'
status_response = requests.get(ROR_API_ENDPOINT + '?' + f'query="{key}"').json()
status_response

# %%
dict_ror2 = {}
for m, a in enumerate(df_ad2.address.unique()[0:10]):
    row_id = m
    a_split = re.sub(r"[;,\.]", ";", a).split(";")
    nom_univ = re.sub(r"\[.*\]", "", a_split[0]).strip().replace("&egrave;", "è").replace("&", "%26%"). lower()
    #print(nom_univ)
    #key ='École doctorale Pratiques et théories du sens'
    
    try:
        response = requests.get(ROR_API_ENDPOINT + '?' + f'query="{nom_univ}"').json()
        if response["number_of_results"] > 1 :
            for n, x in enumerate(response["items"]):
                if 'education' in x["types"] :
                    datas = response["items"][n]
                    rors = datas["id"]
        elif response["number_of_results"] == 1 :
            datas = response["items"][0]
            rors = datas["id"]
        else:
             rors = "not found"
        dict_ror2[a] = rors
    except:
        print(nom_univ)

# %%
dict_ror2
#len(df_ad2)

# %%
dict_ror2
df_ad2["ror"] = df_ad2.address.map(dict_ror2.get)
df_ad2
